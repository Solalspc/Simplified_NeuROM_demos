# %% [markdown]
# <!-- ---
# title: Element based 1D HideNN-FEM - L-BFGS training
# format:
#   html:
#     html-math-method: mathjax
#     code-fold: show
# jupyter: python3
# execute:
#   echo: true
# pdf-engine: pdflatex
# --- -->

# %%
import os
os.environ["OMP_NUM_THREADS"] = "128"
os.environ["MKL_NUM_THREADS"] = "128"

# %% [markdown]
# # Element based 1D HideNN-FEM - L-BFGS training - with tensor decomposition
#
# $\forall v\in V(\Omega),$ find $u\in H(\Omega)$,
#
#
# $$\int_\Omega \nabla v \cdot \lambda(x) \nabla u = \int_\Omega f v  + \int_{\partial \Omega_N} g v$$
#
# Avant on cherchait la solution sous la forme $u(x) = u_{model}(x)$.
#
# On rajoute maintenant le module d'Young $E$ de la barre comme paramètre et on cherche la solution sous forme de décomposition tensorielle :
# $$u(x, E) = \sum_{i=1}^m \bar{u}_i(x) \lambda_i(E)$$
#
# Avec chaque monômes $\bar{u}_i(x)$ ou $\lambda_i(E)$ étant un sous-modèle. (voir le schéma de Daby-Seesaram (2026)).
#
# On garde la même discrétisation et le même degré d'interpolation pour les fonctions $\lambda_i$ que pour les modes spatiaux.

# %%
#| code-fold: true

import torch
# At the top of your notebook
# torch.set_num_threads(128)
# print(f"Using {torch.get_num_threads()} CPU threads")  # should print 128

# Set device to cpu
device = torch.device("cpu")

import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook"
from IPython.display import clear_output

# # torch.set_default_dtype(torch.float32)
# print(torch.cuda.is_available())
# print(torch.cuda.get_device_name(0))

# # Set device
# device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

from pgd_plots import *
# Out:
# Using device: cpu

# %% [markdown]
# ## Vectorised version of the Element-based implementation
#
# We recode 1D shape functions in HideNN-FEM (first order).
#
# A vectorised implementation enables batch processing of several points evaluation which in terns enables batch wise differentiation.
#
# * In non-batched implementation
#
#     * `du_dx = [torch.autograd.grad(u[i], x[i], grad_outputs=torch.ones_like(u[i]), create_graph=True) for i,_ in enumerate(u)`
#
# * With the batched version
#     * `du_dx = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), create_graph=True) `

# %%
class mySF1D_elementBased_vectorised(nn.Module):
    def __init__(self, connectivity):            
                                        # on doit maintenant l'init en lui donnant la connectivity table
        super(mySF1D_elementBased_vectorised, self).__init__()
        if connectivity.dim == 1:
            connectivity = connectivity[:,None] # il faut que la connectivity table soit toujours 2D
        self.connectivity = connectivity

        self.register_buffer('GaussPoint',self.GP()) # execute la fonction donc store les points de gauss
        self.register_buffer('w_g',torch.tensor(1.0))


    def UpdateConnectivity(self,connectivity):
        self.connectivity = connectivity.astype(int) # change le type seulement

    def GP(self):
        "Defines the position of the integration point(s) for the given element"

        return torch.tensor([[1/2, 1/2]], requires_grad=True)                                       # a1, a2, th 2 area coordinates

    def forward(self, 
                x               : torch.Tensor  = None  , 
                cell_id         : list          = None  , 
                coordinates     : torch.Tensor  = None  ,    # c est les points du mesh
                flag_training   : bool          = False):

        assert coordinates is not None, "No nodes coordinates provided. Aborting"

        cell_nodes_IDs  = self.connectivity[cell_id,:].T # id des noeus a partir de la connectivity et de l id de l element
        Ids             = torch.as_tensor(cell_nodes_IDs) .to(coordinates.device) .t() [:,:,None]     # si on etait en 2d juste ca rajoute un coord artificiellement pour etre en 3d 
        nodes_coord     = torch.gather(coordinates[:,None,:].repeat(1,2,1), 
                                       0, 
                                       Ids.repeat(1,1,1))    # [:,:,None] usefull only in 2+D  Ids.repeat(1,1,d) with d \in [1,3]
                                                             # so in 2D, repeat(1,1,2) ?
        
        nodes_coord = nodes_coord.to(self.GaussPoint.dtype)

        if flag_training: 
            refCoordg   = self.GaussPoint.repeat(cell_id.shape[0],1)    
            Ng          = refCoordg                                     #valeurs des shapes functions en l'unique point de Gauss de l'élément, mais comme on a un elem P1, on retombe sur les mêmes valeurs donc on confond les refCoordg et Ng ?
            x_g         = torch.einsum('enx,en->ex',nodes_coord,Ng)     #coordonnés des points de gauss dans le vrai mesh (il faudrait mettre refCoordg à la place de Ng si on voulait être plus général ?)
            refCoord    = self.GetRefCoord(x_g,nodes_coord)             #on retrouve les coordonnés des points de Gauss qui ont permis de calculer les x_g
            N           = refCoord                                      # QUESTION : on doit retrouver les valeurs de shapes functions qui ont permis de transporter les points de Gauss, mais c etait justement pas points de depart ?
            detJ        = nodes_coord[:,1] - nodes_coord[:,0]
            # print(N)
            return N, x_g, detJ*self.w_g

        else: 
            refCoord = self.GetRefCoord(x,nodes_coord)
            N = torch.stack((refCoord[:,0], refCoord[:,1]),dim=1)       # on calcule les coordonnes du point a evaluer dans le mesh de reference 
            return N




    def GetRefCoord(self,x, nodes_coord):
        ''''
        dfsgds
        '''
        InverseMapping          = torch.ones([int(nodes_coord.shape[0]), 2, 2], dtype=x.dtype, device=x.device)
        detJ                    = nodes_coord[:,0,0] - nodes_coord[:,1,0]
        InverseMapping[:,0,1]   = -nodes_coord[:,1,0]
        InverseMapping[:,1,1]   = nodes_coord[:,0,0]
        InverseMapping[:,1,0]   = -1*InverseMapping[:,1,0]
        InverseMapping[:,:,:]  /= detJ[:,None,None]
        x_extended = torch.stack((x, torch.ones_like(x)),dim=1)


        return torch.einsum('eij,ej...->ei',InverseMapping,x_extended.squeeze(1))

# %% [markdown]
# #### Recall on the iso-parametric Finite Element Method
#
# In 1D, for P1 elements, there are two shape functions per element, $N_1\left(\xi\right)$ and $N_2\left(\xi\right)$, $\xi \in \left[0,1\right]$ being the coordinate in the reference element space.
#
# The iso-parametric idea relies on using the same interpolation for the space coordinates as is used for the QoIs, which means that space is interpolated using the same shape functions as the displacement is for instance.
# Thus, the real space coordinate $x$ satisfies
# * $x = \sum_{i=1}^{2}N_i\left(\xi \right) x_i$,
#
#  with $x_i$ the coordinate of the node associated with the $i-$ th shape function.
#
#  Such mapping can be expressed using the area coordinates $a_1$ and $a_2$ (such that $N_1\left(\xi\right) = a_1$ and $N_2\left(\xi\right) = a_2$).
#
# $\begin{pmatrix}
# x \\
# 1
# \end{pmatrix} = \underbrace{\begin{bmatrix}
# x_1 & x_2\\
# 1 & 1
# \end{bmatrix}}_{\mathcal{M}} \begin{pmatrix}
# a_1 \\
# a_2
# \end{pmatrix}.$
#
#  Reciprocally (for non degenerated elements),
#
# $\begin{pmatrix}
# a_1 \\
# a_2
# \end{pmatrix} = \underbrace{\frac{1}{x_1 - x_2}\begin{bmatrix}
# 1 & -x_2\\
# -1 & x_1
# \end{bmatrix}}_{\mathcal{M}^{-1}} \begin{pmatrix}
# x \\
# 1
# \end{pmatrix}.$

# %% [markdown]
# ## Mesh generation

# %%
N_u           = 17
nodes_u       = torch.linspace(0,6.28,N_u)
nodes_u       = nodes_u[:,None] # pq il l etend ?
elements_u    = torch.vstack([torch.arange(0,N_u-1),torch.arange(1,N_u)]).T

N_E = 25
nodes_E =   torch.linspace(1e2, 1e3, N_E)
nodes_E =   nodes_E[:,None]
elements_E    = torch.vstack([torch.arange(0,N_E-1),torch.arange(1,N_E)]).T

# %% [markdown]
# ## Assembly using the vectorised element block

# %% [markdown]
# ### Un monôme

# %%
def inv_softplus(y):
    return torch.log(-torch.expm1(-y)) + y # numerically stable HMM ok.. merci claude

class interpolation1D(nn.Module):    
    def __init__(self, 
            nodes           : torch.Tensor  = None  , 
            elements        : list          = None  , 
            dirichlet       : list          = None  ,                 # Fixed nodes (by default, 2 extremities of the beam)
            n_components    : int           = 1     ,                    # Number of dofs per node 
            r_adaptivity : bool               = False
            ):                                 
        super().__init__()
        self.r_adaptivity = r_adaptivity

        if r_adaptivity:
            self.a = nodes[0][0].item()
            assert self.a == 0
            self.b = nodes[-1][0].item()
            self.n_nodes = nodes.numel()

            nodes_squeezed = nodes.squeeze().float()
            assert (nodes_squeezed[1:] > nodes_squeezed[:-1]).all(), \
                "Input nodes must be strictly increasing"

            # Differences between consecutive nodes — always > 0, safe for inv_softplus
            differences = nodes_squeezed[1:] - nodes_squeezed[:-1]  # (n_nodes-1,)
            increments = differences / (self.b - self.a)             # normalize, scale doesn't matter
            coordinates_init = inv_softplus(increments)              # (n_nodes-1,)

            # Sanity check: verify the inverse is correct
            with torch.no_grad():
                recovered_increments = F.softplus(coordinates_init)
                recovered_coords = torch.cumsum(recovered_increments, dim=0)
                recovered_coords = torch.cat([torch.zeros(1), recovered_coords])
                recovered_coords = self.a + (self.b - self.a) * (recovered_coords / recovered_coords[-1])
                assert torch.allclose(recovered_coords, nodes_squeezed, atol=1e-5), \
                    f"Inverse mapping failed: max error = {(recovered_coords - nodes_squeezed).abs().max():.2e}"
                print(f"Inverse mapping OK — max error: {(recovered_coords - nodes_squeezed).abs().max():.2e}")

            self.coordinates = nn.ParameterDict({
                'all': nn.Parameter(coordinates_init, requires_grad=False)
            })

        else:
            # Initialize with the fed mesh
            self.coordinates =nn.ParameterDict({                                            
                                        'all': nn.Parameter(nodes.float(),requires_grad = False)
                                        })
            
        self.n_components                       = n_components
        self.register_buffer('values',0.5*torch.ones((self.get_coordinates().shape[0], self.n_components)))        # QUESTION: a quoi il sert ce register_buffer
        self.dirichlet = dirichlet
        self.elements = elements

        self.Ne = len(elements)

        self.shape_functions = mySF1D_elementBased_vectorised(elements)              

        # To easily transfer to CUDA or change dtype of whole model
        self.register_buffer('one', torch.tensor([1], dtype=torch.float32))

        self.SetBCs()

    def SetBCs(self):
        assert self.n_components == 1, "only scalar field implemented. Aborting"
        if self.n_components == 1:
            self.dofs_free                  = (torch.ones_like(self.values[:])==1)[:,0] #la syntaxe de lenfer
            self.dofs_free[self.dirichlet]  = False
            
            nodal_values_imposed            = 0*self.values[~self.dofs_free,:]              # Not generic yet, only clamped-clamped BCs for now

            nodal_values_free               = self.values[self.dofs_free,:] 
            self.nodal_values               = nn.ParameterDict({
                                                'free'      : nodal_values_free,
                                                'imposed'   : nodal_values_imposed,
                                                })
            # Initialize to False and then we manage in the aggregate training function
            self.nodal_values['imposed'].requires_grad = False
            self.nodal_values['free'].requires_grad = False

    def get_coordinates(self):
        # We're training for the increments, so we compute the right increments to give an uniform mesh once reparametrized
        if self.r_adaptivity:
            # softplus ensures increments > 0 → coordinates strictly increasing
            increments = F.softplus(self.coordinates['all'])#.squeeze()        # shape: (n_nodes,)
            coords = torch.cumsum(increments, dim=0) #- increments       # sorted by construction
            coords = torch.cat((torch.tensor([self.a], device = coords.device), coords))
            # coords = torch.cat([torch.zeros(1), coords])

            # Normalize to fit in [a, b]
            coords =  self.a + (self.b - self.a) * (coords / coords[-1])
            return coords[:, None]
        else:
            # There's no reparametrization
            return self.coordinates['all']#.squeeze()

    def forward(self, x = None): 
        if self.training :
            k_elt = torch.arange(0,self.Ne)                                                            # QUESTION : on fait un forward pass qui va  exciter tout les neurones donc tous les elements ?     

        else :                                                                                 
            k_elt = []
            coords = self.get_coordinates()  # compute once
            for xx in x:
                found = False
                for k in range(self.Ne):
                    elt = self.elements[k]
                    if xx >= coords[elt[0]] and xx <= coords[elt[1]]:
                        k_elt.append(k)
                        found = True
                        break
                if not found:  # catches boundary floating point issues
                    k_elt.append(self.Ne - 1)


        if self.training : # train mode 
            shape_functions, x_g, detJ = self.shape_functions(
                x               = x                 , 
                cell_id         = k_elt             , 
                coordinates     = self.get_coordinates()        , 
                flag_training   = self.training     )
        else:   # eval mode 
            shape_functions = self.shape_functions(
                x               = x                 , 
                cell_id         = k_elt             , 
                coordinates     = self.get_coordinates()        , 
                flag_training   = self.training     )
            
        
        # Batch interpolation of the solution using the computed shape functions batch
        nodal_values_tensor                     = torch.ones_like(self.values) 
        nodal_values_tensor[self.dofs_free,:]   = self.nodal_values['free']
        nodal_values_tensor[~self.dofs_free,:]  = self.nodal_values['imposed']                    

        cell_nodes_IDs      = self.elements[k_elt,:].T
        Ids                 = torch.as_tensor(cell_nodes_IDs).to(nodal_values_tensor.device).t()[:,:,None]      # :,:,None] usefull only in 2+D  

        
        self.nodes_values   = torch.gather(nodal_values_tensor[:,None,:].repeat(1,2,1),
                                        0,
                                        Ids.repeat(1,1,1))    # [:,:,None] usefull only in 2+D  Ids.repeat(1,1,d) with d \in [1,3]
        self.nodes_values   = self.nodes_values.to(shape_functions.dtype)
        # shape_functions is N, th shape function values at the sole Gauss point in the element 
        u = torch.einsum('gi...,gi->g',self.nodes_values,shape_functions) 

        if self.training :
            return u, x_g, detJ
        else:
            return u

# %% [markdown]
# #### Proofing

# %%
def square(x):
    return x*x

# %%
# # nodes_u_non_uniform = square(nodes_u)/nodes_u[-1]
# # test = interpolation1D(nodes=nodes_u_non_uniform, elements=elements_u, dirichlet=[0, nodes_u.shape[0]-1], r_adaptivity=True)
# print("nodes ini :\n",nodes_u_non_uniform.squeeze(-1))
# # print(nodes_u.squeeze(-1).numel())
# coord = test.get_coordinates().squeeze(-1)
# print("after the remap :\n",coord)
# # print(coord.numel())

# %%
# print(list(test.named_parameters()))

# %%
# plt.scatter(nodes_u_non_uniform.numpy(), np.zeros_like(nodes_u.numpy()))

# %% [markdown]
# ### La PGD - somme des modes
#
# Pour la r_adaptivity, on n'entraîne le maillage qu'à partir du second mode.
# Pour laisser cette r-adaptivity comme un outil de raffinage, pas direct. EST-CE PERTINENT ?

# %%
class  PGDapprox(nn.Module):
    def __init__(self,
                 u_nodes          : torch.Tensor = None,
                 E_nodes          : torch.Tensor = None,
                 elements_u       : list         = None,
                 elements_E       : list         = None,
                 max_mode_index : int          = 1,
                 r_adaptivity :bool            = False,
                 train_first_mesh = False,
                 shared_mesh = True):
        
        super().__init__()

        self.max_mode_index = max_mode_index

        dirichlet = [0 ,nodes_u.shape[0]-1]#, nodes_u.shape[0]//2
        self.u_modes = nn.ModuleList(
            [interpolation1D(nodes= u_nodes, elements=elements_u, dirichlet=dirichlet, r_adaptivity=train_first_mesh)] + \
            [interpolation1D(nodes= u_nodes, elements=elements_u, dirichlet=dirichlet, r_adaptivity=r_adaptivity) for _ in range(max_mode_index-1)] #nodes_u.shape[0]-1
        )

        # Force all modes to share the same coordinates parameter
        if r_adaptivity and shared_mesh and (max_mode_index > 1):
            
            if train_first_mesh: start = 0
            else: start = 1

            shared_coords = self.u_modes[start].coordinates['all']  # take from first r_adaptivity mode
            for mode in self.u_modes[start+1:]:                        # assign to all others
                mode.coordinates['all'] = shared_coords


        self.E_modes = nn.ModuleList(
            [interpolation1D(nodes=E_nodes, elements=elements_E, dirichlet=[]) for _ in range(max_mode_index)]
        )
        
        self.current_index = 0

    def forward(self, x=None, E=None):
        if self.training:
            results_u = [self.u_modes[i]() for i in range(self.current_index)]
            results_E = [self.E_modes[i]() for i in range(self.current_index)]

            # Unpack — each u_vals[i] retains its graph to x_gs[i]
            u_vals = [r[0] for r in results_u]   # list of (Ne,) tensors, graphs intact
            x_gs   = [r[1] for r in results_u]   # list of (Ne,) Gauss point tensors
            J_us   = [r[2] for r in results_u]

            lmbda_vals = [r[0] for r in results_E]
            E_gs   = [r[1] for r in results_E]
            J_Es   = [r[2] for r in results_E]

            coordinates_nodes_u = [self.u_modes[i].get_coordinates() for i in range(self.current_index)]

            return u_vals, lmbda_vals, x_gs, E_gs, J_us, J_Es, coordinates_nodes_u

        else:  # inference: Σ u_i(x) · E_i(E)
            # I want to return as much displacement field as there is E values
            results = []
            for E_val in E:
                u_val = sum(self.u_modes[i](x) * self.E_modes[i](E_val.unsqueeze(0)) for i in range(self.current_index))
                results.append(u_val)
            return results

# %%
max_num_mode = 3
model_ex = PGDapprox(u_nodes=nodes_u, E_nodes=nodes_E, elements_u=elements_u, elements_E=elements_E, max_mode_index=max_num_mode, r_adaptivity=True, shared_mesh=False)

print(model_ex.u_modes[1].coordinates['all'].data_ptr())
print(model_ex.u_modes[2].coordinates['all'].data_ptr())  # should print True
# Out:
# Inverse mapping OK — max error: 4.77e-07
# Inverse mapping OK — max error: 4.77e-07
# 709564032
# 711515456

# %%
# print(list(model_ex.named_parameters()))

trainable     = [(n, p) for n, p in model_ex.named_parameters() if p.requires_grad]
frozen        = [(n, p) for n, p in model_ex.named_parameters() if not p.requires_grad]

print(f"Trainable parameters:  {len(trainable)}")
print(f"Frozen parameters:     {len(frozen)}")
# Out:
# Trainable parameters:  0
# Frozen parameters:     18

# %% [markdown]
# ## Training with batch version

# %% [markdown]
# ### Grid intersection

# %%
def intersect_grids(i_grid, j_grid, tol=1e-10):
    # Force 1D regardless of input shape
    i_grid = i_grid.reshape(-1)
    j_grid = j_grid.reshape(-1)

    # 1. Union + sort
    nodes, _ = torch.sort(torch.cat([i_grid, j_grid]))

    # # 2. Remove near-duplicates
    # gaps = torch.diff(merged)                          # guaranteed 1D now
    # keep = torch.cat([torch.tensor([True], device=merged.device), gaps > tol])
    # nodes = merged[keep]

    # # 3. Element quantities
    h         = torch.diff(nodes)
    gauss_pts = nodes[:-1] + 0.5 * h
    det_J     = 0.5 * h

    return det_J, gauss_pts

# %% [markdown]
# ### Energy

# %%
def PotentialEnergy_PGD(u_vals, lmbda_vals, x_gs, E_gs, J_us, J_Es, coordinates_nodes_u, model, f, fault_amp):
    def _debug_stack(name, x):
        if isinstance(x, list):
            x = torch.stack(x)
        # print(f"{name}.shape = {x.shape}")
        return x

    du_dx = []
    for u, x_g in zip(u_vals, x_gs):

        du_dx_i = torch.autograd.grad(
            u,
            x_g,
            grad_outputs=torch.ones_like(u),
            create_graph=True
        )[0]

        du_dx.append(du_dx_i)
    du_dx = torch.stack(du_dx)
    
    
    lmbda_vals = _debug_stack("lmbda_vals", lmbda_vals)
    u_vals = _debug_stack("u_vals", u_vals)
    x_gs   = _debug_stack("x_gs", x_gs)
    J_us   = _debug_stack("J_us", J_us)
    E_gs   = _debug_stack("E_gs", E_gs)
    J_Es   = _debug_stack("J_Es", J_Es)
    du_dx = _debug_stack('du_dx', du_dx)
    # coordinates_nodes_u = _debug_stack('coordinates_nodes_u', coordinates_nodes_u)
    # Experimental
    J_Es  = J_Es.squeeze(-1)[0] 
    J_us  = J_us.squeeze(-1)
    E_gs  = E_gs.squeeze(-1)
    x_gs  = x_gs.squeeze(-1)
    du_dx = du_dx.squeeze(-1)
    # coordinates_nodes_u = coordinates_nodes_u.squeeze(-1)

    lmbda_vals = _debug_stack("lmbda_vals", lmbda_vals)
    u_vals = _debug_stack("u_vals", u_vals)
    x_gs   = _debug_stack("x_gs", x_gs)
    J_us   = _debug_stack("J_us", J_us)
    E_gs   = _debug_stack("E_gs", E_gs)
    J_Es   = _debug_stack("J_Es", J_Es)
    # coordinates_nodes_u = _debug_stack('coordinates_nodes_u', coordinates_nodes_u)
    # print(J_Es)

    
    ## gradient term
    # grad_term = torch.einsum('ie,je,e,ixk,jxk,x->', lmbda_vals, lmbda_vals, J_Es, )
    E_g = E_gs[0]

    ## Le terme spatial est plus compliqué due au différentes grids.
    # Diag term
    param_term_diag = torch.einsum('ne,ne,e,e->n', lmbda_vals, lmbda_vals, E_g, J_Es)
    space_term_diag = torch.einsum('nx,nx,nx->n', du_dx, du_dx, J_us) # lui est correct
    grad_term_diag_term = torch.einsum('n,n->', space_term_diag, param_term_diag)

    # Cross term
    param_term_whole = torch.einsum('me,ne,e,e->mn', lmbda_vals, lmbda_vals, E_g, J_Es)

    n_mode = u_vals.shape[0]
    cross_terms = []
    for i in range(n_mode):
        for j in range(i):
            i_grid, j_grid = coordinates_nodes_u[i], coordinates_nodes_u[j]
            J_u_intersect, gauss_points_intersect = intersect_grids(i_grid, j_grid, tol = 1e-7)
            gauss_points_intersect = gauss_points_intersect.detach().requires_grad_(True)  # ← this must be here

            model.u_modes[i].eval()
            model.u_modes[j].eval()

            # I need to go evaluate the i and j modes at those new gauss points
            u_i = model.u_modes[i](gauss_points_intersect)
            u_j =  model.u_modes[j](gauss_points_intersect)

            du_i_dx = torch.autograd.grad(u_i, gauss_points_intersect,
                                            grad_outputs=torch.ones_like(u_i),
                                            create_graph=True#create_graph_list[i]
                                            )[0]
            du_j_dx = torch.autograd.grad(u_j, gauss_points_intersect,
                                            grad_outputs=torch.ones_like(u_j),
                                            create_graph= True#create_graph_list[j]
                                            )[0]
            
            model.u_modes[i].train()
            model.u_modes[j].train()

            space_term_ij = (du_i_dx*du_j_dx*J_u_intersect).sum()
            cross_terms.append(space_term_ij*param_term_whole[i,j])
            
    
    grad_term_triangular_term = (2 * torch.stack(cross_terms).sum() if cross_terms else torch.tensor(0.0, device=du_dx.device, dtype=du_dx.dtype))
    grad_term = 2*grad_term_triangular_term + grad_term_diag_term

    ## volumic term
    f_tensor = f(x_gs, fault_amp)
    f_tensor  = f_tensor.squeeze(-1) 
    f_tensor   = _debug_stack("f_tensor", f_tensor)

    space_term_vol = torch.einsum('kx,kx,kx->k', f_tensor, u_vals, J_us)
    param_term_vol = torch.einsum('ke,e->k', lmbda_vals, J_Es)

    volumic_term = torch.einsum('k,k->', space_term_vol, param_term_vol)
        
    # for k in range(len(u_vals)):
    #     E_term_volumic = torch.sum(lmbda_vals[k]*J_Es)
    #     u_term_volumic = torch.sum(u_vals[k]*f_tensor*J_us)

    #     volumic_term += E_term_volumic*u_term_volumic
        
    energy    =  0.5*grad_term - volumic_term

    return energy

## force volumique (le poids par exemple)
def f(x, fault_amp):
    # x: shape [k, d] or [d]
    
    if x.dim() == 1:
        fault = torch.zeros_like(x)
        fault[x.numel() // 4] = 1
        return 1000 * (torch.ones_like(x) + fault)

    # x is [k, d]
    k, d = x.shape
    fault = torch.zeros_like(x)

    idx = d // 4
    fault[:, idx] = fault_amp  # apply per row

    return 1000 * (torch.ones_like(x) + fault)

# %% [markdown]
# ### Aggregate training function

# %%
def train_PGD(
    nodes_u=nodes_u, nodes_E=nodes_E,
    elements_u=elements_u, elements_E=elements_E,
    mode_by_mode_nodal_values=False,
    max_num_mode=5, r_adaptivity=False, mode_by_mode_r_adapt=True, shared_mesh=True, train_first_mesh=False,
    Nepoch=[500, 500, 500, 500, 500], save_plot_rate=500,
    lr=0.1, eta=1e-5, optimizer_type='Adam',
    results=None,
    f=f, fault_amp=0,
    log_parameters=False
):
    assert results is not None
    # if optimizer_type not in ['Adam', 'LBFGS', 'AdamW']:
    #     raise ValueError(f"Unknown optimizer: {optimizer_type}")

    model = PGDapprox(
        u_nodes=nodes_u.clone(), E_nodes=nodes_E.clone(),
        elements_u=elements_u.clone(), elements_E=elements_E.clone(),
        max_mode_index=max_num_mode,
        r_adaptivity=r_adaptivity, shared_mesh=shared_mesh, train_first_mesh=train_first_mesh
    ).to(device)

    if not isinstance(lr, list):
        lr = max_num_mode * [lr]
    if not isinstance(optimizer_type, list):
        lr = max_num_mode * [lr]

    results["model"] = model
    model.train()
    lossLists = []

    for k in range(max_num_mode):
        model.current_index += 1
        idx = model.current_index  # 1-based
        print(f"\nAdding mode {idx}")

        ######
        # Si r adaptivity
        if r_adaptivity:
            # Si on est au premier mode, on suit la consigne
            if model.current_index == 1:
                 model.u_modes[0].coordinates['all'].requires_grad = train_first_mesh

            else :     
                # Si on entraîne un par un, on désactive tous les grads puis on active que le courant
                if mode_by_mode_r_adapt:
                    for i in range(model.current_index):
                        model.u_modes[i].coordinates['all'].requires_grad = False
                    model.u_modes[model.current_index - 1].coordinates['all'].requires_grad = True
                # Sinon on active tous les grads
                else :
                     for i in range(model.current_index):
                        model.u_modes[i].coordinates['all'].requires_grad = True

        #######
        # On gére l'adaptation des valeurs nodales
        # On entraîne tout le temps le premier mode
        
        # Si on est au premier mode, on adapte toujours
        if model.current_index == 1:
                model.u_modes[0].nodal_values.free.requires_grad = True
                model.E_modes[0].nodal_values.free.requires_grad = True
        else :     
            # Si on entraîne un par un, on désactive tous les grads puis on active que le courant
            if mode_by_mode_nodal_values:
                for i in range(model.current_index):
                    model.u_modes[i].nodal_values.free.requires_grad = False
                    model.E_modes[i].nodal_values.free.requires_grad = False
                
                model.u_modes[model.current_index - 1].nodal_values.free.requires_grad = True
                model.E_modes[model.current_index - 1].nodal_values.free.requires_grad = True
            # Sinon on active tous les grads
            else:
                # print(range(model.current_index))
                for i in range(model.current_index):
                    model.u_modes[i].nodal_values.free.requires_grad = True
                    model.E_modes[i].nodal_values.free.requires_grad = True

        if log_parameters:
            trainable = [name for name, p in model.named_parameters() if p.requires_grad]
            print(f"############# TRAINABLE PARAMETERS for mode {idx}")
            print(trainable)

        # --- store initial Gauss points from first mode ---
        if idx == 1:
            _, _, L_x_g_ini, _, _, _, _ = model()
            results['x_gauss_ini'] = L_x_g_ini[0].squeeze(-1).detach()

        # --- optimizer ---
        trainable_params = filter(lambda p: p.requires_grad, model.parameters())
        if optimizer_type[k] == 'Adam':
            optimizer = torch.optim.Adam(trainable_params, lr=lr[k])
        elif optimizer_type[k] == 'AdamW':
            optimizer = torch.optim.AdamW(trainable_params, lr=lr[k], weight_decay=1e-2)
        else:
            optimizer = torch.optim.LBFGS(trainable_params, line_search_fn="strong_wolfe")

        def closure():
            optimizer.zero_grad()
            L_u, L_lmbda, L_x_g, L_E_g, L_J_u, L_J_E, L_coords = model()
            loss = PotentialEnergy_PGD(L_u, L_lmbda, L_x_g, L_E_g, L_J_u, L_J_E, L_coords, model, f, fault_amp)
            loss.backward()
            return loss

        # --- training loop ---
        n_epochs = Nepoch[k] if k < len(Nepoch) else Nepoch[-1]
        lossTraining = []

        for i in range(n_epochs):
            optimizer.step(closure)
            loss = closure()
            lossTraining.append(loss.item())

            if (i % save_plot_rate == 0) and not log_parameters:
                clear_output(wait=True)
                plt.figure(figsize=(6, 4))
                plt.plot(lossTraining)
                plt.title(f"Mode {idx} — Epoch {i}/{n_epochs}")
                plt.xlabel("Epoch")
                plt.ylabel("Loss")
                plt.grid(True)
                plt.tight_layout()
                plt.show()
                results['model']     = model
                results['lossLists'] = lossLists

        lossLists.append(lossTraining)
        print(f"{i = } | loss = {loss.data:.2e}")

        # --- stagnation check ---
        if len(lossLists) > 1:
            stagnation_indic = abs(
                2 * (lossLists[-2][-1] - lossLists[-1][-1]) /
                    (lossLists[-2][-1] + lossLists[-1][-1])
            )
            print(f"stagnation indicator = {stagnation_indic:.6e}")
            if stagnation_indic < eta:
                print("Stopping due to stagnation")
                break

    results['model']     = model
    results['lossLists'] = lossLists

# %%
x = torch.linspace(0,5, 20)
y = f(x, fault_amp=1)

fig = go.Figure()
fig.add_trace(go.Scatter( x = x, y=y, mode='lines+markers', name="Non-uniform load", line=dict(color='#01426a')))
fig.update_layout(
    margin=dict(l=0, r=0, t=0, b=0),
    plot_bgcolor='rgba(0,0,0,0)',  # Remove background color
    width=350, 
    height=200,  
    xaxis=dict(title='x',
    showgrid=True,
    gridcolor='lightgray'),
    yaxis=dict(title='f',
    tickvals=[-4.022e8, -4.016e8, -4.008e8],
    ticktext=['-4.022e8', '-4.016e8', '-4.008e8'],
    showgrid=True,
    gridcolor='lightgray',),
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="00ed9f48-d0eb-4761-844b-6a29089dcd54" class="plotly-graph-div" style="height:200px; width:350px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("00ed9f48-d0eb-4761-844b-6a29089dcd54")) {                    Plotly.newPlot(                        "00ed9f48-d0eb-4761-844b-6a29089dcd54",                        [{"line":{"color":"#01426a"},"mode":"lines+markers","name":"Non-uniform load","x":{"dtype":"f4","bdata":"AAAAAKK8hj6ivAY\u002f8xpKP6K8hj\u002fKa6g\u002f8xrKPxzK6z+ivAZANpQXQMprKEBeQzlA8hpKQIbyWkAbymtAr6F8QKK8hkBsKI9ANpSXQAAAoEA="},"y":{"dtype":"f4","bdata":"AAB6RAAAekQAAHpEAAB6RAAAekQAAPpEAAB6RAAAekQAAHpEAAB6RAAAekQAAHpEAAB6RAAAekQAAHpEAAB6RAAAekQAAHpEAAB6RAAAekQ="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{" ...

# %% [markdown]
# # Test runs

# %% [markdown]
# ## no r-adapt + nodal values one by one + meshes one by one + different meshes

# %% [markdown]
# ### Training and definition

# %%
N_u           = 25
nodes_u       = torch.linspace(0,6.28,N_u)
nodes_u       = nodes_u[:,None] # pq il l etend ?
elements_u    = torch.vstack([torch.arange(0,N_u-1),torch.arange(1,N_u)]).T

N_E = 25
nodes_E =   torch.linspace(1e2, 1e3, N_E)
nodes_E =   nodes_E[:,None]
elements_E    = torch.vstack([torch.arange(0,N_E-1),torch.arange(1,N_E)]).T

# %%
results_ref = {}
max_num_mode_ref = 3

train_PGD(
    nodes_u=nodes_u,
    elements_u=elements_u,
    nodes_E=nodes_E,
    elements_E=elements_E,
    max_num_mode    = max_num_mode_ref,
    Nepoch          = [200, 200, 200],
    save_plot_rate       = 50,
    lr              = [1e-1, 1e-2, 1e-2],
    r_adaptivity              = False,
    mode_by_mode_nodal_values = False,
    # mode_by_mode_r_adapt      = True,
    # shared_mesh     = False,
    # train_first_mesh= False,
    eta             = 1e-8,
    optimizer_type='Adam',
    fault_amp       = 0,           # On ajoute de l'asymétrie
    results = results_ref,
    # log_parameters=True
)
# Out:
# i = 199 | loss = -2.37e+07
# stagnation indicator = 4.141665e-06

# %%
## Unpacking

model_ref = results_ref['model'] 
lossLists = results_ref['lossLists']
x_gauss_ini = results_ref['x_gauss_ini']

## Saving
# torch.save(model.state_dict(), "model_weights_4.pt")

# %% [markdown]
# ### Total loss

# %%
plot_loss(lossLists)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="cf6ebe13-a489-4e76-a2ea-2902682ca050" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cf6ebe13-a489-4e76-a2ea-2902682ca050")) {                    Plotly.newPlot(                        "cf6ebe13-a489-4e76-a2ea-2902682ca050",                        [{"line":{"color":"#01426a"},"mode":"lines","name":"Loss","y":[-711624.375,-1156224.375,-1509565.5,-1903215.25,-2369879.75,-2905247.25,-3491825.0,-4125351.5,-4821531.0,-5609556.0,-6498531.5,-7464596.0,-8446826.0,-9392315.0,-10310428.0,-11271297.0,-12262984.0,-13236321.0,-14126098.0,-14997626.0,-15845770.0,-16613932.0,-17299264.0,-17922508.0,-18507386.0,-18988156.0,-19374440.0,-19710984.0,-19965890.0,-20158992.0,-20312362.0,-20467792.0,-20667328.0,-20849216.0,-20996336.0,-21174758.0,-21387556.0,-21573952.0,-21728204.0,-21887452.0,-22041334.0,-22171480.0,-22289472.0,-22383456.0,-22471262.0,-22557178.0,-22622804.0,-22677708.0,-22735930.0,-22794722.0,-22850062.0,-22901398.0,-22955568.0,-23007492.0,-23057448.0,-23105156.0,-23145806.0,-23180884.0,-23214682.0,-23247840.0,-23274806.0,-23297448.0,-23320258.0,-23342352.0,-23362554.0,-23381160.0,-23398444.0,-23415638.0,-23431892.0,-23446382.0,-23460238.0,-23473334.0,-23484864.0,-23495136.0,-23504146.0,-23512182.0,-23520118.0,-23527454.0,-23533912.0,-23540058.0,-23546240.0,-23551998.0,-23557096.0,-23561606.0,-23565838.0,-23569832.0,-23573258.0,-23576240.0,-23579260.0,-23582166.0,-23584658.0,-23587014.0,-23589336.0,-23591454.0,-23593336.0,-23595128.0,-23596846.0,-23598336.0,-23599626.0,-23600876.0,-23602046.0,-23603140.0,-23604148.0,-23605094.0,-23605988.0,-23606832.0,-23607602.0,-23608254.0,-23608784.0,-23609152.0,-23609152.0,-23608484.0,-23606336.0,-23601030.0,-23589702.0,-23570358.0,-23551102.0,-23556662.0,-23592576.0,-23613560.0,-23595548.0,-23578882.0,-23596394.0,-23614356.0,-23602916.0,-23593380.0,-23606402.0,-23613896.0,-23605498.0,-23603998.0,-23611864.0,-23613048.0,-23609374.0,-23610520.0,-23613740.0,-23613894.0,-23612916.0,-23613634.0,-23615002.0,-23615394.0,-23615172.0,-23615382.0,-23616086.0,-23616736.0,-23616658.0,-23616390.0,-23617026.0,-23617884.0,-23617556.0,-23617086.0,-23617870.0,-23618656.0,-23618138.0,-23617722.0,-23618470.0,-23619068.0,-23618682.0,-23618340.0,-23618762.0,-23619294.0,-23619202.0,-23618898.0,-23618990.0,-23619386.0,-23619566.0,-23619382.0,-23619274.0,-23619454.0,-23619686.0,-23619710.0,-23619598.0,-23619636.0,-23619764.0,-23619832.0,-23619842.0,-23619844.0,-23619906.0,-23619960.0,-23619980.0,-23619986.0,-23620008.0,-23620052.0,-23620120.0,-23620162.0,-23620170.0,-23620158.0,-23620160.0,-23620200.0,-23620236.0,-23620290.0,-23620306.0,-23620310.0,-23620320.0,-23620348.0,-23620354.0,-23620376.0,-23620386.0,-23620390.0,-23620410.0,-23620402.0,-22430426.0,-22739460.0,-22929350.0,-23063152.0,-23179810.0,-23269542.0,-23321688.0,-23341486.0,-23345786.0,-23349106.0,-23356270.0,-23365776.0,-23375144.0,-23384322.0,-23395666.0,-23411158.0,-23430348.0,-23450760.0,-23469810.0,-23486198.0,-23500082.0,-23512272.0,-23523280.0,-23532982.0,-23540894.0,-23546852.0,-23551322.0,-23555176.0,-23559078.0,-23563156.0,-23567152.0,-23570800.0,-23574192.0,-23577572.0,-23581106.0,-23584624.0,-23587858.0,-23590698.0,-23593128.0,-23595284.0,-23597292.0,-23599066.0,-23600536.0,-23601726.0,-23602766.0,-23603806.0,-23604862.0,-23605900.0,-23606888.0,-23607856.0,-23608838.0,-23609824.0,-23610720.0,-23611468.0,-23612044.0,-23612516.0,-23612944.0,-23613324.0,-23613684.0,-23614002.0,-23614336.0,-23614722.0,-23615154.0,-23615578.0,-23615962.0,-23616312.0,-23616634.0,-23616932.0,-23617136.0,-23617322.0,-2 ...

# %% [markdown]
# ### Different modes

# %%
plot_modes(model_ref)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="26e82b4b-667d-4e84-9025-a03c944e648c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("26e82b4b-667d-4e84-9025-a03c944e648c")) {                    Plotly.newPlot(                        "26e82b4b-667d-4e84-9025-a03c944e648c",                        [{"mode":"lines","name":"Mode 1","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7QIHXvEAH2r1AjNy+QBLfv0CX4cBAHeTBQKLmwkAo6cNArevEQDPuxUC48MZAPvPHQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAANyUnTs6DLs937Y5PlqSiz69XLo+9YzoPm4ICz9gyiE\u002fPEM4P8E7Tj9FNGQ\u002fzCx6P2LKhz8nRpI\u002f7MGcP7E9pz+SrrE\u002fSJG7P\u002f1zxT+yVs8\u002faDnZPx0c4z88Yuw\u002fzJT1P1zH\u002fj\u002f2\u002fANAPZYIQPwtDUBdZBFAwJoVQCPRGUCEBx5A5z0iQEp0JkBdeSpAhEIuQKoLMkDQ1DVA9505QB5nPUBFMEFAseFEQOgxSEAggktAVtJOQI4iUkDFclVA\u002fMJYQDMTXEDSQl9AqhBiQITeZEBcrGdANHpqQA5IbUDlFXBAveNyQJaxdUCuKHhA+Gh6QEKpfECM6X5A6pSAQBC1gUA11YJAWvWDQH8VhUDxH4ZA5POGQNbHh0DJm4hAu2+JQK5DikChF4tAk+uLQIW\...\u002fHktAw2xHQH66Q0A+CEBA+lU8QLyjOEB48TRAOD8xQPSMLUCz2ilAcigmQDJ2IkDtwx5AZV4aQKrHFUDuMBFAM5oMQHgDCEC8bANAAKz9P4p+9D8KUes\u002fnCPiPxz22D+uyM8\u002fLpvGP79tvT8\u002fQLQ\u002f77eqP2YMoD\u002fyYJU\u002fabWKP\u002fYJgD\u002fZvGo\u002f82VVP+AOQD\u002fktyo\u002f52AVP+sJAD\u002fdZdU+5LeqPusJgD7ktyo+5LeqPQAAAAA="},"type":"scatter"},{"mode":"lines","name":"Mode 2","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7Q ...

# %%
model_ref.eval()

x_test = torch.linspace(0, 6.28, 50)

# ======================
# PARAMÈTRES MANUELS
# ======================
E1 = 110.0
E2 = 900.0

# --- run 1 ---
E_test = torch.tensor([E1, E2])
plot_displacement_field(model_ref, E_test)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="591adbc7-09b1-4b4d-ba48-d83823952291" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("591adbc7-09b1-4b4d-ba48-d83823952291")) {                    Plotly.newPlot(                        "591adbc7-09b1-4b4d-ba48-d83823952291",                        [{"mode":"markers","name":"E = 110","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":""},"type":"scatter"},{"mode":"markers","name":"E = 900","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAA304D4Trlw\u002f7B6iPx1m0z9qGQFAyF8XQK29LEAOgUBA9kdTQE0LZUClQHVAXGiCQO5JiUCq3o9A36OVQKHrmkBYvp9AeZ+jQJmAp0CAF6pAVXisQAx+rkDlRK9AvguwQMsdsED3MK9AJESuQJaNrECp06lAuxmnQKTSo0DPMZ9A+5CaQCjwlUAoXY9A7ruIQLQagkDM6XRAZ3NjQAr9UUCjhkBABm0rQMePFUAHZf8\u002ff6rTP\u002fzCnj+lrlM\u002fpa7TPgAAAAA="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %% [markdown]
# ### Midpoint deflection versus $E$

# %%
plot_midpoint_vs_E(model_ref)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="b33d8712-91a6-45c7-9b53-6de930c58672" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b33d8712-91a6-45c7-9b53-6de930c58672")) {                    Plotly.newPlot(                        "b33d8712-91a6-45c7-9b53-6de930c58672",                        [{"mode":"markers","name":"PGD model","x":{"dtype":"f4","bdata":"..."},"y":[47.22687530517578,44.444828033447266,41.66277313232422,38.88072967529297,36.09868240356445,33.970787048339844,31.936355590820312,29.90192222595215,27.867488861083984,26.652082443237305,25.709678649902344,24.76727294921875,23.824865341186523,22.822011947631836,21.782888412475586,20.743764877319336,19.70464324951172,18.97508430480957,18.55509376525879,18.135103225708008,17.71510887145996,17.20798683166504,16.555631637573242,15.903275489807129,15.250921249389648,14.708227157592773,14.494539260864258,14.280853271484375,14.067164421081543,13.823156356811523,13.366907119750977,12.910654067993164,12.454402923583984,11.998151779174805,11.880606651306152,11.76305866241455,11.645513534545898,11.52796745300293,11.215888977050781,10.876018524169922,10.536149024963379,10.19627857208252,10.060018539428711,9.991626739501953,9.923236846923828,9.85484790802002,9.66447639465332,9.400915145874023,9.13735294342041,8.873793601989746,8.721170425415039,8.679487228393555,8.637805938720703,8.596121788024902,8.491190910339355,8.280869483947754,8.070547103881836,7.860224723815918,7.69591760635376,7.66961669921875,7.643316268920898,7.617016315460205,7.572537899017334,7.400819778442383,7.229105472564697,7.0573883056640625,6.885672569274902,6.86891508102417,6.852155685424805,6.835397243499756,6.818638801574707,6.6911091804504395,6.54775333404541,6.404401779174805,6.261046886444092,6.217772006988525,6.207856178283691,6.197940349578857,6.188024044036865,6.107706069946289,5.985146999359131,5.8625874519348145,5.740030288696289,5.676690578460693,5.672571659088135,5.66845178604126,5.664332866668701,5.621341705322266,5.5135698318481445,5.405797958374023,5.2980241775512695,5.217637538909912,5.219407558441162,5.221177577972412,5.222947120666504,5.212257385253906,5.114355564117432,5.016454696655273,4.918552398681641,4.820651531219482],"type":"scatter"},{"line":{"color":"red","dash":"dash"},"mode":"lines","name":"Analytical u(L\u002f2)","x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"JjFFQmPCNELS2iZCw+8aQoObEELKkQdCjDD\\u002fQMJ9+0AE5vdAMGj0QC8D8UD9te1Ao3\u002fqQDdf50DbU+RAvlzhQBd53kArqNtAROnYQLg71kDlntNALxLRQASVzkDWJsxAIcfJQGR1x0AmMcVA8\u002fnCQFnPwEDwsL5AUZ68QByXukDzmrhAfam2QGPCtEBV5bJAAxKxQCJIr0Bqh61Ak8+rQF4gqkCHeahA0tqmQANEpUDhtKNANS2iQMqsoEBsM59A7MCdQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %% [markdown]
# ## r-adapt + nodal values one by one + meshes one by one + different meshes

# %% [markdown]
# ### Training and definition

# %%
N_u           = 25
nodes_u       = torch.linspace(0,6.28,N_u)
nodes_u       = nodes_u[:,None] # pq il l etend ?
nodes_u_non_uniform = square(nodes_u)/nodes_u[-1]
elements_u    = torch.vstack([torch.arange(0,N_u-1),torch.arange(1,N_u)]).T

N_E = 25
nodes_E =   torch.linspace(1e2, 1e3, N_E)
nodes_E =   nodes_E[:,None]
elements_E    = torch.vstack([torch.arange(0,N_E-1),torch.arange(1,N_E)]).T

# %%
results_1 = {}
max_num_mode_1 = 3

train_PGD(
    nodes_u=nodes_u_non_uniform,
    elements_u=elements_u,
    nodes_E=nodes_E,
    elements_E=elements_E,
    max_num_mode    = max_num_mode_1,
    Nepoch          = [500, 500, 500, 500, 500],
    save_plot_rate       = 100,
    lr              = [1e-2, 1e-3, 1e-4, 1e-4, 1e-4],
    r_adaptivity    = True,
    mode_by_mode_nodal_values = True,
    mode_by_mode_r_adapt      = True,
    shared_mesh     = False,
    train_first_mesh= True,
    eta             = 1e-8,
    optimizer_type='Adam',
    fault_amp       = 0,           # On ajoute de l'asymétrie
    results = results_1,
    # log_parameters=True
)
# Out:
# i = 499 | loss = -2.19e+07
# stagnation indicator = 5.793387e-02

# %%
## Unpacking

model = results_1['model']
lossLists = results_1['lossLists']
x_gauss_ini = results_1['x_gauss_ini']

## Saving
# torch.save(model.state_dict(), "model_weights_4.pt")

# %% [markdown]
# ### Total loss

# %%
plot_loss(lossLists)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="684b48a0-c31a-431d-b131-8dd5ac3dddbe" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("684b48a0-c31a-431d-b131-8dd5ac3dddbe")) {                    Plotly.newPlot(                        "684b48a0-c31a-431d-b131-8dd5ac3dddbe",                        [{"line":{"color":"#01426a"},"mode":"lines","name":"Loss","y":[-42786.75,-168989.25,-284316.25,-389858.1875,-486544.5625,-575224.875,-656809.8125,-732248.5625,-802443.3125,-868206.4375,-930276.5625,-989346.9375,-1046072.125,-1101053.625,-1154826.625,-1207854.375,-1260532.75,-1313204.125,-1366161.5,-1419653.0,-1473884.625,-1529027.875,-1585227.125,-1642604.375,-1701256.375,-1761257.375,-1822657.875,-1885499.75,-1949820.5,-2015642.5,-2082976.25,-2151821.5,-2222172.75,-2294027.25,-2367377.0,-2442211.75,-2518514.75,-2596267.25,-2675446.25,-2756032.75,-2838005.25,-2921346.5,-3006026.25,-3092019.25,-3179296.25,-3267825.75,-3357575.75,-3448509.25,-3540596.25,-3633796.25,-3728073.0,-3823382.75,-3919687.25,-4016945.0,-4115116.0,-4214158.0,-4314026.5,-4414690.5,-4516110.5,-4618258.5,-4721114.5,-4824655.5,-4928874.0,-5033763.5,-5139313.5,-5245526.5,-5352399.5,-5459932.5,-5568123.5,-5676976.5,-5786488.5,-5896656.5,-6007478.5,-6118950.0,-6231067.0,-6343818.0,-6457203.5,-6571208.0,-6685822.0,-6801035.0,-6916826.5,-7033181.5,-7150079.0,-7267490.0,-7385390.0,-7503739.0,-7622501.5,-7741642.0,-7861128.5,-7980923.0,-8100993.0,-8221305.5,-8341840.0,-8462567.0,-8583437.0,-8704335.0,-8825388.0,-8947028.0,-9068454.0,-9189909.0,-9311796.0,-9433393.0,-9555332.0,-9677264.0,-9799124.0,-9921250.0,-10043100.0,-10165150.0,-10287047.0,-10408840.0,-10530661.0,-10652200.0,-10773700.0,-10895017.0,-11016055.0,-11137002.0,-11257641.0,-11378024.0,-11498217.0,-11618059.0,-11737628.0,-11856918.0,-11975855.0,-12094441.0,-12212715.0,-12330626.0,-12448115.0,-12565243.0,-12681982.0,-12798279.0,-12914125.0,-13029519.0,-13144434.0,-13258852.0,-13372737.0,-13486053.0,-13598788.0,-13710932.0,-13822452.0,-13933334.0,-14043571.0,-14153133.0,-14262016.0,-14370226.0,-14477783.0,-14584690.0,-14690912.0,-14796410.0,-14901162.0,-15005162.0,-15108415.0,-15210924.0,-15312702.0,-15413726.0,-15513957.0,-15613338.0,-15711787.0,-15809266.0,-15905775.0,-16001286.0,-16095782.0,-16189257.0,-16281702.0,-16373095.0,-16463418.0,-16552594.0,-16640637.0,-16727571.0,-16813414.0,-16898174.0,-16981878.0,-17064572.0,-17146296.0,-17226996.0,-17306648.0,-17385270.0,-17462856.0,-17539368.0,-17614788.0,-17689124.0,-17762370.0,-17834500.0,-17905472.0,-17975260.0,-18043884.0,-18111300.0,-18177464.0,-18242354.0,-18305960.0,-18368336.0,-18429432.0,-18489206.0,-18547636.0,-18604724.0,-18660500.0,-18714980.0,-18768128.0,-18819964.0,-18870584.0,-18920004.0,-18968244.0,-19015348.0,-19061498.0,-19106840.0,-19151420.0,-19195280.0,-19238470.0,-19281112.0,-19323242.0,-19364848.0,-19405934.0,-19446556.0,-19486748.0,-19526480.0,-19565738.0,-19604496.0,-19642768.0,-19680552.0,-19717840.0,-19754588.0,-19790810.0,-19826520.0,-19861736.0,-19896468.0,-19930724.0,-19964496.0,-19997826.0,-20030688.0,-20063152.0,-20095214.0,-20126848.0,-20158100.0,-20188976.0,-20219484.0,-20249616.0,-20279408.0,-20308824.0,-20337832.0,-20366436.0,-20394640.0,-20422628.0,-20450674.0,-20478592.0,-20505918.0,-20532592.0,-20559006.0,-20585424.0,-20611620.0,-20637276.0,-20662516.0,-20687658.0,-20712668.0,-20737248.0,-20761418.0,-20785460.0,-20809376.0,-20832900.0,-20856072.0,-20879116.0,-20901976.0,-20924516.0,-20946790.0,-20968880.0,-20990756.0,-21012394.0,-21033778.0,-21054948.0,-21075938.0,-21096704.0,-21117260.0,-21137568.0,-21157696.0,-21177646.0,-21 ...

# %% [markdown]
# ### Nodes displacement (only for r - adaptivity)

# %%
plot_node_displacement(model, nodes_u_non_uniform)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="5ac3b352-f584-439a-bc0d-2b2e4cf0dc9d" class="plotly-graph-div" style="height:350px; width:750px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5ac3b352-f584-439a-bc0d-2b2e4cf0dc9d")) {                    Plotly.newPlot(                        "5ac3b352-f584-439a-bc0d-2b2e4cf0dc9d",                        [{"name":"Mode 1","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAJQCzLvwfVQ7jPuxPFiqWj1ahcs91MUkPmJ0dD7Fv6o+W6rjPiEdEj\u002fsazU\u002fVetZP3aUeT\u002f6tnQ\u002f1BAZP8CuMD1kWg2\u002fogeFv6ZGob\u002fM0pC\u002f0B9gvxAZFr9QApa+AAAAAA=="},"type":"bar"},{"name":"Mode 2","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAJQkoLuAuc67iNwRvLBTTbzwmo280Em9vGAl9ryQ0xu9QApBvWDkZL1APkC94CADvQCoVrwAetc7ADCoPEBUMT0AKGe9AFMuvvACKL4g5A++AA7dvQAwh72AvgC9AAAAAA=="},"type":"bar"},{"name":"Mode 3","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAOi5g7oAEG26gN5CugABCroAsIW5ANCLOAAg5DkA\u002fF06AJqpOgAM3ToAYAM7ACIYOwAmKzsA+EM7AAxmOwAUhTsARIk7AJyDOwCwbjsA+FQ7ADAzOwA4CjsA0LI6AAAAAA=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[ ...

# %% [markdown]
# ### Different modes

# %%
plot_modes(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="86d98c92-8029-4bbd-b403-0a97d0d5bd8c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("86d98c92-8029-4bbd-b403-0a97d0d5bd8c")) {                    Plotly.newPlot(                        "86d98c92-8029-4bbd-b403-0a97d0d5bd8c",                        [{"mode":"lines","name":"Mode 1","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7QIHXvEAH2r1AjNy+QBLfv0CX4cBAHeTBQKLmwkAo6cNArevEQDPuxUC48MZAPvPHQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAEkAzD3oc0k+WmSWPnEXyD5iCPg+PAgUP1IXLD\u002fYfUM\u002fFo5aP3SKcT+7PYQ\u002fnX+PP4CAmj8be6U\u002fvUCwP14Guz9WlsU\u002fIvjPP+9Z2j9nd+Q\u002fgXDuP51p+D8SIgFAcNoFQM2SCkArSw9AiAMUQIZ+GECfvRxAt\u002fwgQNA7JUDoeilAALotQBj5MUAxODZASXc6QGG2PkDvY0JAOqZFQIboSEDRKkxAHG1PQGivUkC08VVA\u002fzNZQEx2XECWuF9A4vpiQC49ZkB5f2lAxsFsQBEEcEBdRnNAqYh2QPTKeUA+DX1AxSeAQOvIgUB0P4NA1BeEQDPwhECSyIVA8qCGQFF5h0CwUYhAECqJQHACikDP2opALrOLQI6LjEDsY41ATDyOQKwUj0AL7Y9AasWQQMqdkUApdpJAiE6TQOgmlEBH\...\u002foWOQ\u002f8HvaPz\u002ftzz+BSsU\u002f0qe6PwwFsD9lYqU\u002fO5aaP4spjz\u002fUvIM\u002fSqBwP9zGWT9+7UI\u002fDxQsP7uQEz8x8fU+68DEPqaQkz4WwUQ+FsHEPW4FqzU="},"type":"scatter"},{"mode":"lines","name":"Mode 2","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7QIHXvEAH2r1AjNy+QBLfv0CX4cBAHeTBQKLmwkAo6cNArevEQDPuxUC48MZAPvPHQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAFZMdj5F9Xk+cfp+Pkp+gj670IU+PQeJPsjlij5Sx ...

# %% [markdown]
# ### Displacement of the Gauss point (trick)

# %%
plot_gauss_displacement(model, x_gauss_ini)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="1445654c-6c60-45c2-9ba0-05a8fa6e0da2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1445654c-6c60-45c2-9ba0-05a8fa6e0da2")) {                    Plotly.newPlot(                        "1445654c-6c60-45c2-9ba0-05a8fa6e0da2",                        [{"mode":"markers","name":"Mode 1 \u2014 displaced pts","x":{"dtype":"f4","bdata":"blEMPGqC6zy8I289bTLKPWKoFj6+P08+CfCGPkvoqD4Agc0+pD71PnCmED\u002fcJio\u002fLA9LP38dgz++UcI\u002fTk0TQOhuTkDSZYRAXUicQMADq0CI0bJAAMC4QPjHvkDrcsVA"},"y":{"dtype":"f4","bdata":"Lu1xPng75z7tSCM\u002fKRlkP1symD\u002fG9cI\u002ftznxP6kkEUB48SpA1ydGQNt6Y0BUEoJAbB2WQEBBt0CYHvJAz1kXQW1kIkEdaBNBT1XlQIGPqkAu34VAn\u002fFNQAASBUANZzs\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 2 \u2014 displaced pts","x":{"dtype":"f4","bdata":"7lkBPNySBj3ctqA9vIcWPlAjdD4mmbQ+ENr6PtVpJj\u002f2QVU\u002f9+OEPwbKoD+79r0\u002ftErdP0Yb\u002fz\u002fKAxJA7sUlQKCQPkBXH11A2K95QC6giUDerpZA7iSkQHJFskCXQ8FA"},"y":{"dtype":"f4","bdata":"sARfPrq69D6CTEM\u002fthmYPwWY3j+ejxlADPVJQDRxf0BpNpxAgyq5QINn1UCAge5Ae0YDQcTgDUEPzhZBi94dQZGuIUH3uyBBV6kZQfp8DUEqnfhA82\u002fIQI+ciEBJNcw\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 3 \u2014 displaced pts","x":{"dtype":"f4","bdata":"zxjDOwYc5zw205I9qjQMPnBFZT5XTqo+tB3tPqKIHT\u002fiFEo\u002f0DZ8PwL5mT9eorg\u002fthbaP5RU\u002fj+YrBJAwJInQGLhPUA3m1VAa75uQFikhECwnJJAnEihQBqosEBCvcBA"},"y":{"dtype":"f4","bdata":"pS8oPoF35T7Jczg\u002fkU6QPzWW0z93JhJA+aRAQKtGdEDGh5VAAd2xQFNdz0CIFepAgyICQUOqDUGmFRdBu2UeQb2jIUEllSFBihEeQVUhE0FPVwNBCw\u002fTQBCykED\u002fS9k\u002f"},"type":"scatter"},{"marker":{"size":8,"symbol":"cross"},"mode":"markers","name":"Initial Gauss pts","x":{"dtype":"f4","bdata":"kqGyO\u002fZJ3zxHI5E9OY4LPgLfZD4AQqo+lj7tPqSyHT8JW0o\u002feph8P3s1mj8+6bg\u002fiGfaP1qw\u002fj\u002fY4RJAxtAnQPgkPkBu3lVAJ\u002f1uQJLAhEAytZJAclyhQFS2sEDYwsBA"},"y":{"dtype":"f4","bdata":"1v0ZPi9U4j5UJDc\u002f7tCPP+FI0z+VHRJARbtAQIB7dEC5sZVAkxGyQOqSz0BVUOpAST8CQW\u002fDDUE7LBdB7HceQeunIUGQjSFBR\u002fgdQV8BE0H3LANBZMXSQNZqkECqwNg\u002f"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %% [markdown]
# On plotte $u$ aux points de Gauss en fin de training (qui sont sont donc indicateurs de comment on été déplacés les noeuds du maillage) et aux points de Gauss initiaux (sauvegardés suite à l'initialisation).

# %%
model.eval()

x_test = torch.linspace(0, 6.28, 50)

# ======================
# PARAMÈTRES MANUELS
# ======================
E1 = 110.0
E2 = 900.0

# --- run 1 ---
E_test = torch.tensor([E1, E2])
plot_displacement_field(model, E_test)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="d671ff3b-6151-486d-9c11-6c33db017b7b" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d671ff3b-6151-486d-9c11-6c33db017b7b")) {                    Plotly.newPlot(                        "d671ff3b-6151-486d-9c11-6c33db017b7b",                        [{"mode":"markers","name":"E = 110","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAL0SNkBQzaRAekXrQOE6F0HUGTdB+VtVQZ5CckG4R4ZBK1mTQd8on0EIAapBlym0QYx+vUEWBcZBubXNQWOn1EFb9tpBODjgQbZw5UF40OhB0S\u002fsQY8d7kFp8+5BRcnvQQKX8EGWGe9BG43tQff460HtDepBvIPlQXIA4UE1hdxB3FzVQYg0zkHv\u002fcZBxGq\u002fQWrstEHFcapBlU6fQXzLk0FC+oZBVItxQfFRVUGxdDZBzggWQSYy5kBXhZxAEhAeQHRCATc="},"type":"scatter"},{"mode":"markers","name":"E = 900","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAKDLNT\u002fzeJE\u002fXaXFP6d\u002f9z8+dxNAHeIpQKZYP0C5TFNA7blmQPONeEB4iYRAAymMQKXdkkCOu5hA\u002foeeQGA\u002fpEDWQ6lAUR2tQFbtsEDt1rJA5L60QJwitkDDUrdA7IK4QLCSuUA3NLhAjca2QEI6tUAgZrNAmEqwQJ1KrUDXfqpA5P+kQPKAn0AfyZlAWxyUQKtTjEC9mYRAGoF4QDINZ0BRrFNAyGA+QLpmKUAYehJAi8L0P5Zmuz+4YH4\u002fjFMAP4S1vjU="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...

# %% [markdown]
# ### Midpoint deflection versus $E$

# %%
plot_midpoint_vs_E(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="c4866ec7-0a59-4d4c-9354-e85911638f6c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c4866ec7-0a59-4d4c-9354-e85911638f6c")) {                    Plotly.newPlot(                        "c4866ec7-0a59-4d4c-9354-e85911638f6c",                        [{"mode":"markers","name":"PGD model","x":{"dtype":"f4","bdata":"..."},"y":[30.387758255004883,30.058420181274414,29.729080200195312,29.399738311767578,29.070398330688477,28.40049934387207,27.68195915222168,26.963415145874023,26.244871139526367,25.524171829223633,24.802749633789062,24.081323623657227,23.359893798828125,22.65708351135254,21.96544075012207,21.2737979888916,20.582155227661133,19.918046951293945,19.281478881835938,18.644908905029297,18.008337020874023,17.426725387573242,16.93667221069336,16.446624755859375,15.95657730102539,15.488739967346191,15.087565422058105,14.686392784118652,14.2852201461792,13.89441204071045,13.576166152954102,13.25792121887207,12.939675331115723,12.621431350708008,12.360886573791504,12.100341796875,11.83979606628418,11.579251289367676,11.356868743896484,11.139938354492188,10.923007011413574,10.706073760986328,10.513684272766113,10.329474449157715,10.145263671875,9.961051940917969,9.792861938476562,9.634285926818848,9.4757080078125,9.317131042480469,9.168829917907715,9.030805587768555,8.892782211303711,8.754755973815918,8.623026847839355,8.501812934875488,8.380595207214355,8.259380340576172,8.141629219055176,8.03423023223877,7.926834583282471,7.819437026977539,7.713521957397461,7.617980480194092,7.522439479827881,7.4268975257873535,7.331356048583984,7.245041370391846,7.158726692199707,7.072412490844727,6.986097812652588,6.9082417488098145,6.8315935134887695,6.754946231842041,6.678297519683838,6.605254650115967,6.533413410186768,6.461572170257568,6.389731407165527,6.324221611022949,6.262510299682617,6.200798988342285,6.139087677001953,6.077314376831055,6.015476703643799,5.953639984130859,5.891802787780762,5.834444046020508,5.784546375274658,5.73464822769165,5.684750080108643,5.633816719055176,5.579771995544434,5.525728702545166,5.47168493270874,5.4192352294921875,5.377935886383057,5.336638450622559,5.295339107513428,5.254040241241455],"type":"scatter"},{"line":{"color":"red","dash":"dash"},"mode":"lines","name":"Analytical u(L\u002f2)","x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"JjFFQmPCNELS2iZCw+8aQoObEELKkQdCjDD\\u002fQMJ9+0AE5vdAMGj0QC8D8UD9te1Ao3\u002fqQDdf50DbU+RAvlzhQBd53kArqNtAROnYQLg71kDlntNALxLRQASVzkDWJsxAIcfJQGR1x0AmMcVA8\u002fnCQFnPwEDwsL5AUZ68QByXukDzmrhAfam2QGPCtEBV5bJAAxKxQCJIr0Bqh61Ak8+rQF4gqkCHeahA0tqmQANEpUDhtKNANS2iQMqsoEBsM59A7MCdQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0. ...

# %% [markdown]
# ### Compared to the ref solution

# %%
compute_error_vs_ref(model, model_ref, plot=True)
# Out:
# === Error vs. reference ===
#   relative_norm             : 1.9188e-01
#   mean_relative_error       : 1.6315e-01
#   max_relative_error        : 1.6499e+01
#   l2_absolute               : 2.2385e+00
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="40913f95-eb4d-4950-bfb2-7d239d0dbc27" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("40913f95-eb4d-4950-bfb2-7d239d0dbc27")) {                    Plotly.newPlot(                        "40913f95-eb4d-4950-bfb2-7d239d0dbc27",                        [{"colorbar":{"len":0.75,"title":{"text":"Rel Error"},"y":0.625},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"name":"Heatmap","x":{"dtype":"f4","bdata":"AAAAAN7pgT3e6QE+zd5CPt7pgT5WZKI+zd7CPkRZ4z7e6QE\u002fGicSP1ZkIj+RoTI\u002fzd5CPwkcUz9EWWM\u002fgJZzP97pgT98CIo\u002fGieSP7hFmj9WZKI\u002f84KqP5Ghsj8vwLo\u002fzd7CP2v9yj8JHNM\u002fpzrbP0RZ4z\u002fid+s\u002fgJbzPx61+z\u002fe6QFALfkFQHwICkDLFw5AGicSQGk2FkC4RRpAB1UeQFZkIkCkcyZA84IqQEKSLkCRoTJA4LA2QC\u002fAOkB+zz5Azd5CQBzuRkBq\u002fUpAuQxPQAgcU0BXK1dApjpbQPVJX0BEWWNAk2hnQOJ3a0Awh29Af5ZzQM6ld0AdtXtAbMR\u002fQN7pgUCF8YNALfmFQNQAiEB7CIpAIxCMQMoXjkByH5BAGSeSQMEulEBoNpZAED6YQLdFmkBfTZxABlWeQK5coEBVZKJA\u002fWukQKRzpkBMe6hA84KqQJqKrEBCkq5A6ZmwQJGhskA4qbRA4LC2QIe4uEAvwLpA1se8QH7PvkAl18BAzd7CQHTmxEAc7sZAw\u002fXIQA=="},"y":{"dtype":"f4","bdata":"AADIQhW87EIVvAhDIBobQyp4LUM01j9DPzRSQ0qSZENU8HZDL6eEQzTWjUM6BZdDPzSgQ0RjqUNKkrJDT8G7Q1TwxENZH85DXk7XQ2R94ENprOlDbtvyQ3QK\u002fEO8nAJEPzQHRMHLC0REYxBExvoUREmSGUTMKR5ETsEiRNFYJ0RT8CtE1ocwRFkfNUTbtjlEXk4+RODlQkRjfUdE5hRMRGisUETrQ1VEbttZRPByXkRzCmNE9qFnRHg5bET70HBEfWh1RAAAekQ="},"z":{"dtype":"f4","bdata":"AAAAAOQ53j1UkWk+E6mKPtERlT7+eJs+q\u002fOfPmDLoj5STqU+FRinPrBzqD64Qqo+MsmqPgJxqz6fhKw+iEmtPhJLrj56M68+5NiuPo0srj4Zbq8+8UKwPm5NsD7Y6rA+5H6xPletsT5p4bE+LnGyPlX6sj5ufbM+p3izPkGmsz5P0rM+5vyzPh5AtD7uS7Q+cle0PrRitD6xbbQ+pOi0PqXltD634rQ+0N+0PvPctD7b\u002fbU+dBi2PvMytj5QTbY+lWe2PrqBtj5JHLY+pmi1PnujtT6g3rU+Fxq2Pt9Vtj6yDrY+0aC0Pigtsz4b6rI+ImezPi\u002fmsz4mZ7Q+xwezPguHsT55xbA+xmCxPrgAsj6JpbI+L8WyPic7sT6hlK8+\u002frSsPipyrT5ChK4+RqSvPn9BsD79mK4+JGKtPhCprD5K4as+4girPrdsqj6F\u002f6w+E4OsPnKfqj6fT6g+HbGmPoxkpj7tCqY+3ZymPkhuqD5yJKQ+kcOgPurwnT4PtZk+BmaWPt5llj7NZZY+8vyDQQAAAAAHBwA9YQYcPtrhSD6WIV4+TD5rPkFxdD6XPXo+8W9\\u002f4w+uTyMPgXYjD75d40+whyOPl0tjj4sZYw+l32KPtVYhz6sOYg+tHmJPvrJij4Iios+5cWJPt9xiD7smYc+zLCGPkq0hT7Q+YQ+ssiHPrUwhz6SFoU+vYiCPtLAgD6TcYA+1BSAPlG\u002fgD7jzoI+bB58PiCbdD4gVG4+4elkPkKOXT7jjV0+yI1dPmpjgUEAAAAA6ieKPR2DXj3348o9mQn2PTtjCD73zRE+kK4XPuANHT5y1CA+AKcjPpC1Jz6NuSg+JjYqPuPHLD4chi4+gLkwPgC2Mj55kzE+1VcwPsn7Mz4ChjY+8cw2Pvo4OD5jjzk+Vuk5PsrJOT58aTo+2QE7PnyTOz7H3Ds+V\u002fk8PjsMPj4DFj8+WxVAPtwqQD7oP0A+a1RAPnNoQD7XIkE+9mZAPrKtPz709j4+uEI+Pg41QT5b7kE+06ZCPnxeQz5nFUQ+eMtEPkVCRD6gm0I+otVCPu8PQz6BSkM+aoVDPsZ2Qj5Pgj4+3n06PmIcOj4nAjw+2e89PiflPz7NKT0+ECA6PraXOD7Dzjk+JQ87PjNZPD52Uzw+nCA4PnCnMz5EqSw+XckuPsvCMT7U4jQ+NL82PoDvMj4l\u002fC8+bPwtPhzUKz7pfSk+A7snPiX4LT6pgSw+ccAnPnQEIj6VCh4+IGgdPvOpHD6EQx4++gkjPvRVGD4Y1Q8+QroIPnsk\u002fD2ffOs903vrPZZ76z3Bk31BAAAAAAFtFj7I24k8KJf9PIIpWj07XIk9sUCdPfmmqT2FDbU9Dwy9PW38wj10ncs92dPNPWcy0T1b4dY9xqDaPZ4k3z22N+M9UZ3gPXTF3j1xc+c9h7HtPYCk7j2LovE9FXP0Pekl9T12EvQ9BGP0Pcmv9D1I+fQ9Kxv2PQx6+T2du\u002fw9d+H\u002fPWxFAT6LWwE+FXEBPiuGAT68mgE+YBECPqDLAD7nFP89KJv8PSIq+j3AVwA+OHIBPoiLAj6GowM+YboEPvPPBT4cjgU+WNkDPtnWAz5N1AM+xNEDPjjPAz4FagI+Psz7PcGf8j33L\u002fI9CjX3PfBO\u002f ...
# ({'relative_norm': 0.19188429415225983,
#   'mean_relative_error': 0.16314533352851868,
#   'max_relative_error': 16.49850845336914,
#   'l2_absolute': 2.2385406494140625},
#  tensor([[0.0000e+00, 1.6595e+00, 2.8633e+00,  ..., 2.4741e+00, 1.2370e+00,
#           7.7880e-06],
#          [0.0000e+00, 1.6072e+00, 2.7864e+00,  ..., 2.4203e+00, 1.2101e+00,
#           7.6346e-06],
#          [0.0000e+00, 1.5550e+00, 2.7094e+00,  ..., 2.3665e+00, 1.1832e+00,
#           7.4812e-06],
#          ...,
#          [0.0000e+00, 4.6922e-01, 6.7570e-01,  ..., 4.6701e-01, 2.3350e-01,
#           1.3250e-06],
#          [0.0000e+00, 4.6572e-01, 6.6884e-01,  ..., 4.6031e-01, 2.3015e-01,
#           1.3029e-06],
#          [0.0000e+00, 4.6223e-01, 6.6197e-01,  ..., 4.5361e-01, 2.2680e-01,
#           1.2809e-06]]),
#  tensor([[0.0000, 1.8615, 3.7094,  ..., 3.5031, 1.7515, 0.0000],
#          [0.0000, 1.6591, 3.2872,  ..., 3.0885, 1.5443, 0.0000],
#          [0.0000, 1.4567, 2.8650,  ..., 2.6740, 1.3370, 0.0000],
#          ...,
#          [0.0000, 0.2060, 0.4100,  ..., 0.3870, 0.1935, 0.0000],
#          [0.0000, 0.2004, 0.3967,  ..., 0.3726, 0.1863, 0.0000],
#          [0.0000, 0.1948, 0.3834,  ..., 0.3582, 0.1791, 0.0000]]))

# %% [markdown]
# ## r-adapt + nodal values all at once + meshes one by one + different meshes

# %% [markdown]
# ### Training and definition

# %%
N_u           = 25
nodes_u       = torch.linspace(0,6.28,N_u)
nodes_u       = nodes_u[:,None] # pq il l etend ?
nodes_u_non_uniform = square(nodes_u)/nodes_u[-1]
elements_u    = torch.vstack([torch.arange(0,N_u-1),torch.arange(1,N_u)]).T

N_E = 25
nodes_E =   torch.linspace(1e2, 1e3, N_E)
nodes_E =   nodes_E[:,None]
elements_E    = torch.vstack([torch.arange(0,N_E-1),torch.arange(1,N_E)]).T

# %%
results_2 = {}
max_num_mode_2 = 5

train_PGD(
    nodes_u=nodes_u_non_uniform,
    elements_u=elements_u,
    nodes_E=nodes_E,
    elements_E=elements_E,
    max_num_mode    = max_num_mode_2,
    Nepoch          = [100, 100, 100, 100, 100],
    save_plot_rate       = 25,
    lr              = [1e-2, 1e-2, 1e-2, 1e-2, 1e-2],
    r_adaptivity    = True,
    mode_by_mode_nodal_values = False,
    mode_by_mode_r_adapt      = True,
    shared_mesh     = False,
    train_first_mesh= True,
    eta             = 1e-8,
    optimizer_type='Adam',
    fault_amp       = 0,           # On ajoute de l'asymétrie
    results = results_2,
    # log_parameters=True
)
# Out:
# i = 99 | loss = -2.37e+07
# stagnation indicator = 3.612683e-03

# %%
## Unpacking

model = results_2['model']
lossLists = results_2['lossLists']
x_gauss_ini = results_2['x_gauss_ini']

## Saving
# torch.save(model.state_dict(), "model_weights_4.pt")

# %% [markdown]
# ### Total loss

# %%
plot_loss(lossLists)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="eb4773f0-7491-4408-82ec-22b3525ff71c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eb4773f0-7491-4408-82ec-22b3525ff71c")) {                    Plotly.newPlot(                        "eb4773f0-7491-4408-82ec-22b3525ff71c",                        [{"line":{"color":"#01426a"},"mode":"lines","name":"Loss","y":[-42786.75,-168989.25,-284316.25,-389858.1875,-486544.5625,-575224.875,-656809.8125,-732248.5625,-802443.3125,-868206.4375,-930276.5625,-989346.9375,-1046072.125,-1101053.625,-1154826.625,-1207854.375,-1260532.75,-1313204.125,-1366161.5,-1419653.0,-1473884.625,-1529027.875,-1585227.125,-1642604.375,-1701256.375,-1761257.375,-1822657.875,-1885499.75,-1949820.5,-2015642.5,-2082976.25,-2151821.5,-2222172.75,-2294027.25,-2367377.0,-2442211.75,-2518514.75,-2596267.25,-2675446.25,-2756032.75,-2838005.25,-2921346.5,-3006026.25,-3092019.25,-3179296.25,-3267825.75,-3357575.75,-3448509.25,-3540596.25,-3633796.25,-3728073.0,-3823382.75,-3919687.25,-4016945.0,-4115116.0,-4214158.0,-4314026.5,-4414690.5,-4516110.5,-4618258.5,-4721114.5,-4824655.5,-4928874.0,-5033763.5,-5139313.5,-5245526.5,-5352399.5,-5459932.5,-5568123.5,-5676976.5,-5786488.5,-5896656.5,-6007478.5,-6118950.0,-6231067.0,-6343818.0,-6457203.5,-6571208.0,-6685822.0,-6801035.0,-6916826.5,-7033181.5,-7150079.0,-7267490.0,-7385390.0,-7503739.0,-7622501.5,-7741642.0,-7861128.5,-7980923.0,-8100993.0,-8221305.5,-8341840.0,-8462567.0,-8583437.0,-8704335.0,-8825388.0,-8947028.0,-9068454.0,-9189909.0,-8713492.0,-8995042.0,-9247585.0,-9479732.0,-9694819.0,-9892846.0,-10074592.0,-10241023.0,-10393704.0,-10534756.0,-10666711.0,-10791420.0,-10909822.0,-11022872.0,-11132074.0,-11239170.0,-11345362.0,-11451090.0,-11556486.0,-11661817.0,-11767487.0,-11873788.0,-11980762.0,-12088277.0,-12196159.0,-12304296.0,-12412684.0,-12521230.0,-12629002.0,-12736461.0,-12843420.0,-12949588.0,-13055154.0,-13160090.0,-13264392.0,-13368148.0,-13471504.0,-13574576.0,-13677438.0,-13780144.0,-13882756.0,-13985341.0,-14087886.0,-14190302.0,-14292126.0,-14393268.0,-14494085.0,-14594068.0,-14693196.0,-14792334.0,-14890651.0,-14988259.0,-15085326.0,-15181899.0,-15277674.0,-15372374.0,-15466774.0,-15560598.0,-15653882.0,-15746590.0,-15838254.0,-15928819.0,-16018900.0,-16108757.0,-16196823.0,-16284326.0,-16371292.0,-16457764.0,-16543459.0,-16627754.0,-16711404.0,-16794740.0,-16876832.0,-16957578.0,-17037536.0,-17116516.0,-17194696.0,-17272156.0,-17348584.0,-17424292.0,-17499268.0,-17573452.0,-17646460.0,-17718888.0,-17790498.0,-17861112.0,-17930980.0,-18000068.0,-18068392.0,-18135898.0,-18202572.0,-18268360.0,-18332752.0,-18396544.0,-18459688.0,-18522184.0,-18584050.0,-18644368.0,-18704072.0,-18763246.0,-17884098.0,-18181720.0,-18439016.0,-18655972.0,-18827068.0,-18963260.0,-19076826.0,-19172264.0,-19254138.0,-19328690.0,-19400306.0,-19471520.0,-19543192.0,-19614512.0,-19684660.0,-19753570.0,-19820880.0,-19885792.0,-19948272.0,-20008848.0,-20067606.0,-20124468.0,-20179394.0,-20233118.0,-20285812.0,-20337500.0,-20388260.0,-20438168.0,-20487216.0,-20535432.0,-20582854.0,-20629440.0,-20675176.0,-20720136.0,-20764420.0,-20808048.0,-20851084.0,-20893540.0,-20935402.0,-20974808.0,-21013972.0,-21052808.0,-21091246.0,-21129230.0,-21166790.0,-21203930.0,-21240646.0,-21276956.0,-21312876.0,-21348458.0,-21383672.0,-21418528.0,-21453044.0,-21487276.0,-21521216.0,-21552928.0,-21584492.0,-21615938.0,-21647242.0,-21678360.0,-21709052.0,-21738442.0,-21767730.0,-21796896.0,-21825898.0,-21853788.0,-21881424.0,-21909084.0,-21936752.0,-21963074.0,-21989114.0,-22015022.0,-22040798.0,-22 ...

# %% [markdown]
# ### Nodes displacement (only for r - adaptivity)

# %%
plot_node_displacement(model, nodes_u_non_uniform)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="dd59d24f-2ff4-4c59-8c7f-5a819389065d" class="plotly-graph-div" style="height:350px; width:750px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dd59d24f-2ff4-4c59-8c7f-5a819389065d")) {                    Plotly.newPlot(                        "dd59d24f-2ff4-4c59-8c7f-5a819389065d",                        [{"name":"Mode 1","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAADRBMbxsFIa8APSavNDzj7xADDO8gH0eO0Butzxw+j89yOCRPeDTtD0g07g9gOyYPeBNRD2Az4c8AFCQvEASX73AcsC98G8LvlBWOb5AWWi+YL+CvuD7S76A8LG9AAAAAA=="},"type":"bar"},{"name":"Mode 2","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAPJ4Mry+e4m8pH2cvLiHi7zg+w68ACpRO4BpwDzA0w098I5BPQBvbT2wF4090Ai4PRAk\u002fT3gThw+8OQSPoBPnj0A79+80M4IvnC2Sb5gmUy+oIkhvgCB2b3ADYG9AAAAAA=="},"type":"bar"},{"name":"Mode 3","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAACQsIbzs2Ya8LOzovHBHu7xgJRC8gHVmOwAGfzxAXso8wEf7PGBwBD0AWeI8gP\u002f7PCAcUD2A1pg9wAjNPaCC0T0gS8E9gCqdPUAcXj0Ah\u002fA8AMqVPABurTwA3bQ8AAAAAA=="},"type":"bar"},{"name":"Mode 4","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAKyoEbymqIe8dBvbvCAWzLwgxZm84Lt7vCA7g7xgbZa8oDmwvIBKzryAvfS8wJwLvUB9Gb1AFhO9AMhFvACHnTyAEgw9gMIqPQCL4TwAok08AMCUOwBMgzsADLY7AAAAAA=="},"type":"bar"},{"name":"Mode 5","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAITfDrxAGYq8VFuYvHAqnLwAcC684LsPvAAeMLzAfWG8ANyMvAC1pbxAVbe8AFK8vEAWvrwA\u002fMO8gEqivAClvbxA9QC9AC3YvIBlx7wA87+8APp6vACwPrsA8NY7AAAAAA=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9 ...

# %% [markdown]
# ### Different modes

# %%
plot_modes(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="75d03ef2-3422-4fa5-8b83-865896d315ad" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("75d03ef2-3422-4fa5-8b83-865896d315ad")) {                    Plotly.newPlot(                        "75d03ef2-3422-4fa5-8b83-865896d315ad",                        [{"mode":"lines","name":"Mode 1","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7QIHXvEAH2r1AjNy+QBLfv0CX4cBAHeTBQKLmwkAo6cNArevEQDPuxUC48MZAPvPHQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAGxdyL2E8Q++fViPvUpODzwi29s9OOZSPo1Jlj5cmsI+QdDuPtBjCj99Xx0\u002fK1swPxT8Qj+yaVU\u002fUtdnP\u002fFEej\u002frF4Y\u002fB\u002fuOPyLelz8+waA\u002fNnapP\u002frdsT++Rbo\u002fgq3CP0YVyz+JVdM\u002feyzbP24D4z9g2uo\u002fUrHyP0aI+j+tGgFAK7IEQKhJCEAm4QtAo3gPQCEQE0CfpxZAujkaQNdwHUDzpyBAEN8jQCwWJ0BJTSpAZoQtQIK7MECg8jNAZfY2QC7aOUD2vTxAv6E\u002fQIiFQkBQaUVAGU1IQOEwS0CqFE5AI+lQQIlYU0Dvx1VAVjdYQLymWkAiFl1AiIVfQO70YUBTZGRAutNmQCFDaUBNcWtAL5BtQBCvb0DyzXFA0+xzQLULdkCWKnhAd0l6QFlofEA6h35ADlOAQAvEgEB\u002f84BA8iKBQGdSgUDbgYFATrGBQMPggUA2EIJAqz+CQB5vgkCTnoJAB86CQBa7gkCEmoJA8nmCQGBZgkDNOIJAOhiCQKj3gUAW14FAg7aBQPGVgUBedYFAzFSBQGEmgUCyt4BAA0mAQKm0f0BL135A7vl9QI8cfUAyP3xA1GF7QHaEekAYp3lAu8l4QF3sd0D\u002fDndAEpd1QO7qc0DIPnJAopJwQH3mbkBZOm1AM45rQA3iaUDoNWhAwYlmQJvdZEB2MWNAUIVhQCrZX0D04V1A36tbQMt1WUC1P1dAoQlVQIzTUkB2nVBAYmdOQEwxTEA4+0lAIMVHQAyPRUD3WENA4yJBQMvsPkAHZTxAOao5QGzvNkCbNDRAz3kxQAC\u002fLkAyBCxAY0kpQJeOJkDG0yNA+hghQCpeHkBcoxtAjegYQMItFkAoKBNACeUPQOWhDEDGXglAphsGQIfYAkDGKv8\u002fiKT4P0se8j8DmOs\u002fxhHlP4SL3j9HBdg\u002fCfLQP21ByT\u002fNkME\u002fM+C5P5Mvsj\u002f4fqo\u002fUc6iP7Ydmz8WbZM\u002ffLyLP9sLhD+Btng\u002fByJoP8dGVj+Ha0Q\u002fVZAyPxW1ID\u002fk2Q4\u002fR\u002f35PuVG1j5GkLI+5NmOPsdGVj4C2g4+AtqOPX7JcDU="},"type":"scatter"},{"mode":"lines","name":"Mode 2","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkC ...

# %% [markdown]
# ### Displacement of the Gauss point (trick)

# %%
plot_gauss_displacement(model, x_gauss_ini)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="a950f3d9-c990-465e-8ba3-7335374fb6fd" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a950f3d9-c990-465e-8ba3-7335374fb6fd")) {                    Plotly.newPlot(                        "a950f3d9-c990-465e-8ba3-7335374fb6fd",                        [{"mode":"markers","name":"Mode 1 \u2014 displaced pts","x":{"dtype":"f4","bdata":"Y\u002fExPD1SJz1URLU9tzwePqJ2cz6zb6w+p+TmPhbVFD8oPTs\u002fLi1oP0PIjj9CW64\u002f7Y7SP4SP+j9a6hJAOx8qQOjkQkC6O11AWiN5QFBHi0CSbJpAXKKoQCRKtUC6JsJA"},"y":{"dtype":"f4","bdata":"j4uMPVaegj6dpAw\u002fVrpyPw7stz+LBQBACCkoQOUMVECL7YFAAw+cQB6GuECBldZAgEH0QEKYB0E+nhJBIC8aQSS4HUH6WhxBD+QUQRxaBkH4peBAh2GqQEEpXkDz7Z8\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 2 \u2014 displaced pts","x":{"dtype":"f4","bdata":"Qo0yPAlTKD1z4rU9kA4ePl4Pcj7FrKs+IGrmPl9CFj\u002fy3z8\u002fiiBvPwIXkj86wK4\u002fIr7MP0wC7T86aAlAYcAgQKqLPEDUBFtAUpF5QNIZi0C+bZhAmpWlQHJrs0D0xMFA"},"y":{"dtype":"f4","bdata":"rAaNPe9lgz4vHQ0\u002fknVyPyrotj+C+f4\u002fVNYnQG\u002fhVUASuIRAAeufQNTUu0B97dZAheXvQMNmA0H5Qw5BOa4XQW09HUEKnxxBGboUQXOSBkFXLudA6fe2QM3LcECJ5qg\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 3 \u2014 displaced pts","x":{"dtype":"f4","bdata":"2+YpPPuAJT0KHL89dNElPqUUdT4gnKs+CVzoPh6LGD9wREM\u002f14d0Pwhflj+OLLU\u002fGS\u002fVPzap9j9cSg1AmVYhQMLZN0CYZFBARsxqQDJqg0AK8pFA1rqgQC4FsEBqaMBA"},"y":{"dtype":"f4","bdata":"qjGGPbc0gT4FJhQ\u002fCgZ+P48XuT8l4v4\u002faSYpQHfPWED2woZAFeuiQMwcwEA1htxAzDf2QIJnBkFYERBBW9YXQaziHEHn4h1BQb4ZQRMsD0GdgPtAO3LKQE5WiUBM4cg\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 4 \u2014 displaced pts","x":{"dtype":"f4","bdata":"HyUiPDrEIz3Ke709VAEmPrc8ez4Y\u002f7I+X0f1PkUZIj+kdU8\u002fRUmBP4u7nT8sAb0\u002f8PveP1SxAUDqahRAJJYnQExvPEDFcFNAGMZsQGQchEAyb5JAcDmhQCmPsEAXrMBA"},"y":{"dtype":"f4","bdata":"RBGAPRC2fz6c6BI\u002fXk1+P7SLvT8NoARA0t4xQBQRZUAjGo5AiqeqQPVxx0DZWONAOGb9QDAkCkHtQRNBtoEZQUc7HUEFhh1BPhQZQVWCDkGzIPpAk5nIQMSmhkCxq8I\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 5 \u2014 displaced pts","x":{"dtype":"f4","bdata":"i8AgPDwHJD3acbU9ltYePioVdD6vOq8+\u002fj3yPtrVID90UU4\u002fXrGAP5DvnD+N0Ls\u002fWVzdP0DaAEAgSBRAtjApQIjkP0CGuFdAupxwQD6EhUDqU5NAHKehQGGnsED6p8BA"},"y":{"dtype":"f4","bdata":"Qu99PR0PgD5Txww\u002fm59zP71euD9I+wFAGdIvQD9yY0A3ao1AwweqQEKtxkBtT+JAokP8QJ6sCUGTNBNBZu8ZQR9+HUGQAx1B88kXQSfuDEGmbPdAHgDHQBcuhkBODMM\u002f"},"type":"scatter"},{"marker":{"size":8,"symbol":"cross"},"mode":"markers","name":"Initial Gauss pts","x":{"dtype":"f4","bdata":"kqGyO\u002fZJ3zxHI5E9OY4LPgLfZD4AQqo+lj7tPqSyHT8JW0o\u002feph8P3s1mj8+6bg\u002fiGfaP1qw\u002fj\u002fY4RJAxtAnQPgkPkBu3lVAJ\u002f1uQJLAhEAytZJAclyhQFS2sEDYwsBA"},"y":{"dtype":"f4","bdata":"txYNPQqwLj5wL+I+a+RWP6ldrT9c\u002fPw\u002fhHIsQPxrX0B4B4tAe2WnQDTzw0DFx99AfB76QP7VCEFjmhJBX5EZQVNcHUEAPB1BpFUYQbDLDUHDW\u002flA4BbIQJrjhUA\u002flcA\u002f"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd37 ...

# %% [markdown]
# On plotte $u$ aux points de Gauss en fin de training (qui sont sont donc indicateurs de comment on été déplacés les noeuds du maillage) et aux points de Gauss initiaux (sauvegardés suite à l'initialisation).

# %%
model.eval()

x_test = torch.linspace(0, 6.28, 50)

# ======================
# PARAMÈTRES MANUELS
# ======================
E1 = 110.0
E2 = 900.0

# --- run 1 ---
E_test = torch.tensor([E1, E2])
plot_displacement_field(model, E_test)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="cafbf157-0ad4-4a53-a482-98a161dbe777" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cafbf157-0ad4-4a53-a482-98a161dbe777")) {                    Plotly.newPlot(                        "cafbf157-0ad4-4a53-a482-98a161dbe777",                        [{"mode":"markers","name":"E = 110","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAGBTXkDn1dZAhtocQXJKTEGyVXlBjQKSQeZMpkFLorlBinLLQfiM3EElCOxB9tP6QcADBEKAMQpC9c8PQtHuFEKlaRlCfHkdQo2+IEIIeCNCHu8lQjTFJ0K2zyhCYqApQsfRKULB\u002fyhC0uknQk0YJkLD1CNCtwIhQmKfHUKY4xlCNS8VQtgoEEIVewpCImgEQvfn+kE5VuxB\u002ftncQY97y0Hla7lBqYqmQQy7kUGPqXdBbnNLQdUMG0HQu85A07tOQL5QEDc="},"type":"scatter"},{"mode":"markers","name":"E = 900","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAALBr4D5IUFo\u002f\u002fKmgP8zH0T+0QgBA9l4WQCRgK0D1Xz9ABepRQFSSY0AK0nNAMaGBQEehiED9SI9Aeu6UQJArmkCy2p5Al9WiQOBQpkCGB6lAB2erQDRLrUB+EK5Aq5KuQIvLrkBqJ65AAyOtQDeoq0DiZqlAnz2mQJnKokDl7p5ADO+ZQPyulECa145A6ZGIQJhHgUCAdXNALYFjQL7CUUDC+z5AlY0rQFF0FkCYd\u002f8\u002f7tfRPxtYoD\u002faylU\u002f38rVPgBerTU="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444 ...

# %% [markdown]
# ### Midpoint deflection versus $E$

# %%
plot_midpoint_vs_E(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="e3d753e8-4957-4351-b844-62167b49174d" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e3d753e8-4957-4351-b844-62167b49174d")) {                    Plotly.newPlot(                        "e3d753e8-4957-4351-b844-62167b49174d",                        [{"mode":"markers","name":"PGD model","x":{"dtype":"f4","bdata":"..."},"y":[44.02122497558594,42.595787048339844,41.170352935791016,39.74491500854492,38.319480895996094,35.556365966796875,32.602169036865234,29.647972106933594,26.693777084350586,25.67237663269043,25.295236587524414,24.91809844970703,24.540958404541016,23.522430419921875,22.119075775146484,20.715717315673828,19.312360763549805,18.51372718811035,18.319822311401367,18.12591552734375,17.932008743286133,17.516054153442383,16.729995727539062,15.943936347961426,15.157881736755371,14.531451225280762,14.383931159973145,14.236413955688477,14.088894844055176,13.89973258972168,13.419076919555664,12.938424110412598,12.457764625549316,11.977110862731934,11.855705261230469,11.73430061340332,11.612895011901855,11.491490364074707,11.200551986694336,10.885395050048828,10.570239067077637,10.255080223083496,10.09367561340332,9.98352336883545,9.873370170593262,9.76321792602539,9.59161376953125,9.38314151763916,9.174667358398438,8.966196060180664,8.808199882507324,8.700681686401367,8.59316349029541,8.48564624786377,8.366558074951172,8.22821044921875,8.089862823486328,7.951516151428223,7.822256565093994,7.72022819519043,7.61820125579834,7.516173839569092,7.414773941040039,7.3177642822265625,7.220758438110352,7.12375020980835,7.0267415046691895,6.9376020431518555,6.84846305847168,6.759324073791504,6.670184135437012,6.593376636505127,6.518330097198486,6.443284511566162,6.3682379722595215,6.293905258178711,6.219810485839844,6.145715713500977,6.071620464324951,6.0046539306640625,5.941963195800781,5.8792724609375,5.816582679748535,5.755125522613525,5.69490385055542,5.6346821784973145,5.574460029602051,5.515939712524414,5.460254669189453,5.404571056365967,5.348884582519531,5.29537296295166,5.248377799987793,5.201382637023926,5.154387474060059,5.106755256652832,5.054661273956299,5.00256872177124,4.950475215911865,4.898382186889648],"type":"scatter"},{"line":{"color":"red","dash":"dash"},"mode":"lines","name":"Analytical u(L\u002f2)","x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"JjFFQmPCNELS2iZCw+8aQoObEELKkQdCjDD\\u002fQMJ9+0AE5vdAMGj0QC8D8UD9te1Ao3\u002fqQDdf50DbU+RAvlzhQBd53kArqNtAROnYQLg71kDlntNALxLRQASVzkDWJsxAIcfJQGR1x0AmMcVA8\u002fnCQFnPwEDwsL5AUZ68QByXukDzmrhAfam2QGPCtEBV5bJAAxKxQCJIr0Bqh61Ak8+rQF4gqkCHeahA0tqmQANEpUDhtKNANS2iQMqsoEBsM59A7MCdQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2 ...

# %% [markdown]
# ### Compared to the ref solution

# %%
compute_error_vs_ref(model, model_ref, plot=True)
# Out:
# === Error vs. reference ===
#   relative_norm             : 3.7975e-02
#   mean_relative_error       : 7.2023e-02
#   max_relative_error        : 1.8867e+01
#   l2_absolute               : 4.4302e-01
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="d01d075a-6bbc-4a09-987a-c27fd9b87439" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d01d075a-6bbc-4a09-987a-c27fd9b87439")) {                    Plotly.newPlot(                        "d01d075a-6bbc-4a09-987a-c27fd9b87439",                        [{"colorbar":{"len":0.75,"title":{"text":"Rel Error"},"y":0.625},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"name":"Heatmap","x":{"dtype":"f4","bdata":"AAAAAN7pgT3e6QE+zd5CPt7pgT5WZKI+zd7CPkRZ4z7e6QE\u002fGicSP1ZkIj+RoTI\u002fzd5CPwkcUz9EWWM\u002fgJZzP97pgT98CIo\u002fGieSP7hFmj9WZKI\u002f84KqP5Ghsj8vwLo\u002fzd7CP2v9yj8JHNM\u002fpzrbP0RZ4z\u002fid+s\u002fgJbzPx61+z\u002fe6QFALfkFQHwICkDLFw5AGicSQGk2FkC4RRpAB1UeQFZkIkCkcyZA84IqQEKSLkCRoTJA4LA2QC\u002fAOkB+zz5Azd5CQBzuRkBq\u002fUpAuQxPQAgcU0BXK1dApjpbQPVJX0BEWWNAk2hnQOJ3a0Awh29Af5ZzQM6ld0AdtXtAbMR\u002fQN7pgUCF8YNALfmFQNQAiEB7CIpAIxCMQMoXjkByH5BAGSeSQMEulEBoNpZAED6YQLdFmkBfTZxABlWeQK5coEBVZKJA\u002fWukQKRzpkBMe6hA84KqQJqKrEBCkq5A6ZmwQJGhskA4qbRA4LC2QIe4uEAvwLpA1se8QH7PvkAl18BAzd7CQHTmxEAc7sZAw\u002fXIQA=="},"y":{"dtype":"f4","bdata":"AADIQhW87EIVvAhDIBobQyp4LUM01j9DPzRSQ0qSZENU8HZDL6eEQzTWjUM6BZdDPzSgQ0RjqUNKkrJDT8G7Q1TwxENZH85DXk7XQ2R94ENprOlDbtvyQ3QK\u002fEO8nAJEPzQHRMHLC0REYxBExvoUREmSGUTMKR5ETsEiRNFYJ0RT8CtE1ocwRFkfNUTbtjlEXk4+RODlQkRjfUdE5hRMRGisUETrQ1VEbttZRPByXkRzCmNE9qFnRHg5bET70HBEfWh1RAAAekQ="},"z":{"dtype":"f4","bdata":"AAAAAIOxSTzcquA8F7kuPexCUD3IhmM9EXtzPVkfej2ct3w9Wi2CPe52gT0NvoY9CaaEPRO1gz2T\u002fog9K6yGPft6hT2BtIk9rzqJPXqVhz1LqYg9PtyLPW2rij0L+ok9llqLPY1vjj0pCI09BSmMPYmRjj16PJI9jjCPPU8WjT2ex409VweQPTaTkT0ld4899KaNPb2Ljj2arJE9KpeRPThdkD25J489V\\u002fCWQQAAAACtAm48\u002fsmIO\...\u002fj+zse2kc8RT+cOQWOPDv6lDw7cIE8Owd7PDs2iTw79K48O1B3jUEAAAAASzWOPK+tOD2Ra1g9BjdkPXEXaz39GWs9jdtuPb03dD0fw3E9V0Z4PfIxcD1sE3g9\u002fdR8PeIAcz1jLHo9pn1+PWM0dj3bvHg9uud9PVWSfD1KcnY9+r96PTf7fT0UTnw9grZ2PVTDez1es389\u002fhh8PT4sdT1\u002fpX09\u002fDSCPQhigj1+yIA9e99\u002fPaBKgz1iVIY9RUWGPcurgz01e4Q9TPmEPXp1hT0x8IU9\u002fc+FPTv3gD0Cg4U97HyFPdx2hT3QcIU9cE6DPf8Egz20qIY9eLSFPeb2gz3vNoI9CuJ9Pcapdz0OGoA9InWDPZjNgT0iH4A9gdN8PZK+cT0neXo94yOCPfOvhj3M3YM9pGyAPR\u002fCeT32PXM9Cdd9Pd1jhD0Eo4k94vWGPTFHgj1It3o9sP1zPdUQgj2ctYo9yUGOPX1wjj1Geog9QQCCPWfndD1CB4M9Ik2QPelulj3yt5U9t9GQPUwViz1NRoQ9och0PQ8glj1J5Js9lOSbPezjmz2q45s9KOSbPVblmz1O\\\u002f8Mz2\u002fFzg9k68yPeVnLj1xrjA9RFA3PeOmMD1jsCs90zwsPU2dLz1wnjE9oeUsPb3IKD1J\u002fyk9mmcvPeeULj1uuS09DeEsPZELLD29mSw9nn01PbutLT3P ...
# ({'relative_norm': 0.03797488659620285,
#   'mean_relative_error': 0.07202332466840744,
#   'max_relative_error': 18.867345809936523,
#   'l2_absolute': 0.44301870465278625},
#  tensor([[0.0000e+00, 1.8844e+00, 3.6077e+00,  ..., 3.3173e+00, 1.6587e+00,
#           8.9062e-06],
#          [0.0000e+00, 1.6832e+00, 3.3009e+00,  ..., 3.0974e+00, 1.5487e+00,
#           8.3472e-06],
#          [0.0000e+00, 1.4820e+00, 2.9942e+00,  ..., 2.8775e+00, 1.4387e+00,
#           7.7883e-06],
#          ...,
#          [0.0000e+00, 2.0566e-01, 4.0500e-01,  ..., 3.8685e-01, 1.9343e-01,
#           1.2230e-06],
#          [0.0000e+00, 2.0277e-01, 3.9796e-01,  ..., 3.7904e-01, 1.8952e-01,
#           1.2014e-06],
#          [0.0000e+00, 1.9987e-01, 3.9092e-01,  ..., 3.7123e-01, 1.8562e-01,
#           1.1798e-06]]),
#  tensor([[0.0000, 1.8615, 3.7094,  ..., 3.5031, 1.7515, 0.0000],
#          [0.0000, 1.6591, 3.2872,  ..., 3.0885, 1.5443, 0.0000],
#          [0.0000, 1.4567, 2.8650,  ..., 2.6740, 1.3370, 0.0000],
#          ...,
#          [0.0000, 0.2060, 0.4100,  ..., 0.3870, 0.1935, 0.0000],
#          [0.0000, 0.2004, 0.3967,  ..., 0.3726, 0.1863, 0.0000],
#          [0.0000, 0.1948, 0.3834,  ..., 0.3582, 0.1791, 0.0000]]))

# %% [markdown]
# ## r-adapt + nodal values one by one + meshes all + different meshes

# %% [markdown]
# ### Training and definition

# %%
N_u           = 25
nodes_u       = torch.linspace(0,6.28,N_u)
nodes_u       = nodes_u[:,None] # pq il l etend ?
nodes_u_non_uniform = square(nodes_u)/nodes_u[-1]
elements_u    = torch.vstack([torch.arange(0,N_u-1),torch.arange(1,N_u)]).T

N_E = 25
nodes_E =   torch.linspace(1e2, 1e3, N_E)
nodes_E =   nodes_E[:,None]
elements_E    = torch.vstack([torch.arange(0,N_E-1),torch.arange(1,N_E)]).T

# %%
results_3 = {}
max_num_mode_3 = 5

train_PGD(
    nodes_u=nodes_u_non_uniform,
    elements_u=elements_u,
    nodes_E=nodes_E,
    elements_E=elements_E,
    max_num_mode    = max_num_mode_3,
    Nepoch          = [100, 250, 250, 250, 250],
    save_plot_rate       = 50,
    lr              = [1e-2, 1e-2, 1e-2, 1e-2, 1e-2],
    r_adaptivity    = True,
    mode_by_mode_nodal_values = True,
    mode_by_mode_r_adapt      = False,
    shared_mesh     = False,
    train_first_mesh= True,
    eta             = 1e-8,
    optimizer_type='Adam',
    fault_amp       = 0,           # On ajoute de l'asymétrie
    results = results_3,
    # log_parameters=True
)
# Out:
# i = 249 | loss = -2.34e+07
# stagnation indicator = 2.697027e-03

# %%
## Unpacking

model = results_3['model']
lossLists = results_3['lossLists']
x_gauss_ini = results_3['x_gauss_ini']

## Saving
# torch.save(model.state_dict(), "model_weights_4.pt")

# %% [markdown]
# ### Total loss

# %%
plot_loss(lossLists)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="3c0535de-5823-47af-a19a-afe5a83f0874" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3c0535de-5823-47af-a19a-afe5a83f0874")) {                    Plotly.newPlot(                        "3c0535de-5823-47af-a19a-afe5a83f0874",                        [{"line":{"color":"#01426a"},"mode":"lines","name":"Loss","y":[-42786.75,-168989.25,-284316.25,-389858.1875,-486544.5625,-575224.875,-656809.8125,-732248.5625,-802443.3125,-868206.4375,-930276.5625,-989346.9375,-1046072.125,-1101053.625,-1154826.625,-1207854.375,-1260532.75,-1313204.125,-1366161.5,-1419653.0,-1473884.625,-1529027.875,-1585227.125,-1642604.375,-1701256.375,-1761257.375,-1822657.875,-1885499.75,-1949820.5,-2015642.5,-2082976.25,-2151821.5,-2222172.75,-2294027.25,-2367377.0,-2442211.75,-2518514.75,-2596267.25,-2675446.25,-2756032.75,-2838005.25,-2921346.5,-3006026.25,-3092019.25,-3179296.25,-3267825.75,-3357575.75,-3448509.25,-3540596.25,-3633796.25,-3728073.0,-3823382.75,-3919687.25,-4016945.0,-4115116.0,-4214158.0,-4314026.5,-4414690.5,-4516110.5,-4618258.5,-4721114.5,-4824655.5,-4928874.0,-5033763.5,-5139313.5,-5245526.5,-5352399.5,-5459932.5,-5568123.5,-5676976.5,-5786488.5,-5896656.5,-6007478.5,-6118950.0,-6231067.0,-6343818.0,-6457203.5,-6571208.0,-6685822.0,-6801035.0,-6916826.5,-7033181.5,-7150079.0,-7267490.0,-7385390.0,-7503739.0,-7622501.5,-7741642.0,-7861128.5,-7980923.0,-8100993.0,-8221305.5,-8341840.0,-8462567.0,-8583437.0,-8704335.0,-8825388.0,-8947028.0,-9068454.0,-9189909.0,-8575569.0,-8712412.0,-8836326.0,-8948570.0,-9050223.0,-9142112.0,-9225128.0,-9300227.0,-9368358.0,-9430401.0,-9487134.0,-9539252.0,-9587365.0,-9632027.0,-9673753.0,-9712996.0,-9750147.0,-9785560.0,-9819544.0,-9852380.0,-9884317.0,-9915570.0,-9946326.0,-9976748.0,-10006984.0,-10037176.0,-10067438.0,-10097876.0,-10128582.0,-10159640.0,-10191132.0,-10223132.0,-10255699.0,-10288882.0,-10322730.0,-10357279.0,-10392554.0,-10428594.0,-10465404.0,-10502992.0,-10541384.0,-10580584.0,-10620595.0,-10661417.0,-10703055.0,-10745512.0,-10788792.0,-10832890.0,-10877805.0,-10923540.0,-10970096.0,-11017466.0,-11065646.0,-11114627.0,-11164414.0,-11214994.0,-11266354.0,-11318469.0,-11371360.0,-11425023.0,-11479410.0,-11534458.0,-11590120.0,-11646442.0,-11703476.0,-11761180.0,-11819535.0,-11878569.0,-11938268.0,-11998612.0,-12059553.0,-12121066.0,-12183179.0,-12245838.0,-12309048.0,-12372812.0,-12437154.0,-12502121.0,-12567628.0,-12633672.0,-12700210.0,-12767252.0,-12834853.0,-12902966.0,-12971591.0,-13040730.0,-13110353.0,-13180436.0,-13250950.0,-13321931.0,-13393398.0,-13465332.0,-13537660.0,-13610302.0,-13682964.0,-13755983.0,-13829385.0,-13903172.0,-13977320.0,-14051783.0,-14126559.0,-14201592.0,-14276869.0,-14352446.0,-14428364.0,-14504538.0,-14580719.0,-14657084.0,-14733622.0,-14810268.0,-14887039.0,-14963931.0,-15040974.0,-15118095.0,-15195258.0,-15272478.0,-15349938.0,-15427436.0,-15504984.0,-15582602.0,-15660310.0,-15737853.0,-15814863.0,-15891644.0,-15968404.0,-16044941.0,-16121261.0,-16197495.0,-16273675.0,-16349781.0,-16425770.0,-16501545.0,-16577065.0,-16652109.0,-16726736.0,-16801044.0,-16875038.0,-16948740.0,-17021852.0,-17094272.0,-17166024.0,-17237792.0,-17309800.0,-17380704.0,-17451216.0,-17521656.0,-17591166.0,-17660312.0,-17729108.0,-17796748.0,-17864244.0,-17931188.0,-17997188.0,-18062830.0,-18127632.0,-18191744.0,-18255290.0,-18318058.0,-18379992.0,-18441352.0,-18501786.0,-18561282.0,-18620092.0,-18677670.0,-18734398.0,-18790380.0,-18845078.0,-18898994.0,-18952104.0,-19004282.0,-19055398.0,-19105540.0,-19154678.0,-19203140.0,-19250654 ...

# %% [markdown]
# ### Nodes displacement (only for r - adaptivity)

# %%
plot_node_displacement(model, nodes_u_non_uniform)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="cc50f335-0647-463b-83cd-3b0eaf6a4e18" class="plotly-graph-div" style="height:350px; width:750px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cc50f335-0647-463b-83cd-3b0eaf6a4e18")) {                    Plotly.newPlot(                        "cc50f335-0647-463b-83cd-3b0eaf6a4e18",                        [{"name":"Mode 1","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAANoJ473ug3i+ic3RvuwAG78NQDy\u002fjqhiv8o+bb+mKnu\u002flY2JvwzBhr+AdYO\u002fqm5tv1S\u002fRL+E+CG\u002fEFIav6BXFr907BO\u002fnNgSv4waB7+AbMC+4NyMvkD6Ab4AwoA8AAAAAA=="},"type":"bar"},{"name":"Mode 2","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAJWIkLxODJq8+EMVvPCLkTwEGWo90AnlPVCIPD4siYs+TnzBPrbt\u002fz6LaiM\u002fWWNKP6LRcj8Ys4s\u002fDZeWP5JAVT9gxK+9mNPYvjQtKb9QSwu\u002fgMuRvgDJIb2ASNc9AAAAAA=="},"type":"bar"},{"name":"Mode 3","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAN7tJbyYB+a7YLmwu2jJmrxwnhm9IHV7vfDyu72MGQG+OIYYvjiJLb7ooye+QPUYviDFFL6QckC+QDVlvkBoOr5gd6e9wPlxPbDGAj6A\u002fMc9AJR7vACOqTwAUBK9AAAAAA=="},"type":"bar"},{"name":"Mode 4","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAANJUkLyw4Ja8IE95vBg0o7yQpr28wPzXvEB7+7zAsiW98NtpvaBFa72gJ4C94PWjvXCb5r0gmqy9AMqqveAhpb3A7K29QMb0vcDoCL0ABpI8AFzpvADAK7sA6G47AAAAAA=="},"type":"bar"},{"name":"Mode 5","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAOKaA7xwj7M7IG8SvLCkCLyg9wW8IEsDvMB2D7yAXyW8QNodvICeKrwAqsi7ANA3ugDA0DoAnO27gGAcvcDrTL2AmKa9gOTUvIDNlryA5Te9gDSmvUD2Bb5gKiK+AAAAAA=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...

# %% [markdown]
# ### Different modes

# %%
plot_modes(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="245854e8-049e-4b91-ba2b-49d7d830f725" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("245854e8-049e-4b91-ba2b-49d7d830f725")) {                    Plotly.newPlot(                        "245854e8-049e-4b91-ba2b-49d7d830f725",                        [{"mode":"lines","name":"Mode 1","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7QIHXvEAH2r1AjNy+QBLfv0CX4cBAHeTBQKLmwkAo6cNArevEQDPuxUC48MZAPvPHQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAPwIVjz8CNY8vYYgPXbRVz1L9Yw92gGuPWkOzz33GvA9xJMIPkJxGT6KVSo+1Tk7Ph8eTD5pAl0+s+ZtPv3Kfj6CaIg+k3qRPqSMmj62nqM+xrCsPtfCtT7o1L4++ebHPuHG0T5Kqd0+tIvpPh1u9T5CqAA\u002feJkGP62KDD8mdRI\u002fIPgXPxt7HT8W\u002fiI\u002fEIEoPwwELj8GhzM\u002fAQo5P\u002fyMPj+oekU\u002fsslNP74YVj\u002fGZ14\u002f0bZmP9sFbz\u002fSY3Y\u002fyFx9P+Aqgj9ap4U\u002f1iOJP1GgjD\u002fMHJA\u002fZOmSP9KJlT89Kpg\u002fqcqaPxVrnT+BC6A\u002f7auiP1lMpT\u002fG7Kc\u002fhXmrP2kPrz9NpbI\u002fMju2PxbRuT\u002fnTr0\u002fcd2\u002fP\u002fxrwj+G+sQ\u002fEInHP5oXyj8lpsw\u002fC9TOP3DO0D\u002fSyNI\u002fN8PUP5u91j\u002fNttc\u002fOYbYP6VV2T+o9dk\u002fQQ7aP9om2j90P9o\u002fDFjaPz1r2j\u002fsbNo\u002fm27aP0lw2j\u002f4cdo\u002fpnPaP1V12j8Ed9o\u002fsnjaPyp62j+Geto\u002f43raP0B72j+ce9o\u002f+XvaP1Z82j+yfNo\u002fD33aP2x92j\u002fJfdo\u002fCn7aP0l+2j+Ifto\u002fyH7aPwZ\u002f2j9Gf9o\u002fhH\u002faP8R\u002f2j8EgNo\u002fQoDaP4GA2j+WgNo\u002fpYDaP7SA2j\u002fBgNo\u002f0IDaP96A2j\u002fsgNo\u002f+oDaPwiB2j8Wgdo\u002fJIHaPzKB2j81f9o\u002f9HzaP7N62j9yeNo\u002fMXbaP\u002fBz2j+vcdo\u002fbm\u002faPy1t2j\u002fsato\u002fq2jaP0xT2j+tLto\u002fDgraP27l2T\u002fOwNk\u002fMJzZP5B32T\u002fxUtk\u002fUS7ZP4JN2D\u002fwVtc\u002fXWDWP8tp1T84c9Q\u002fpnzTPxSG0j+Cj9E\u002f75jQP12izz\u002fKq84\u002frQ7LP404xz9uYsM\u002fToy\u002fPzC2uz8M4Lc\u002f7Qm0P9IzsD+vXaw\u002fkIeoP1Q6oz9keJ0\u002fa7aXP3r0kT+GMow\u002flXCGP52ugD9a2XU\u002faVVqP4jRXj+nTVM\u002f2xpHPySpOj97Ny4\u002fxMUhPydUFT9x4gg\u002fjuH4PiH+3z7OGsc+ezeuPidUlT504Xg+zhpHPvNTFT4CG8c9mhpHPQAAAAA="},"type":"scatter"},{"mode":"lines","name":"Mode 2","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPz ...

# %% [markdown]
# ### Displacement of the Gauss point (trick)

# %%
plot_gauss_displacement(model, x_gauss_ini)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="d3978d7f-cbde-44e4-9c6f-5659b0fd65b3" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d3978d7f-cbde-44e4-9c6f-5659b0fd65b3")) {                    Plotly.newPlot(                        "d3978d7f-cbde-44e4-9c6f-5659b0fd65b3",                        [{"mode":"markers","name":"Mode 1 \u2014 displaced pts","x":{"dtype":"f4","bdata":"DF55PaztUD6SUMs+Z9ckPz7YZD+mSpI\u002ffEmvP67zyD\u002f4vug\u002fxjkDQGCoD0DU\u002fxpAhHkjQCgvLEAsazpA\u002fOVNQHttY0ARt3pAxh2JQJ81k0B9H51AQsunQNx9skB4gsBA"},"y":{"dtype":"f4","bdata":"jpHNPj5epz\u002f5WB1AsBl0QJnOoUDJ8MRAmDHhQM8790DSigdBFe8QQS9SF0EKNBxBslAfQUfIIUE0pSRBpkgmQXAcI0ESsxpBIpkNQfJf\u002f0CCNdxAJBmwQIo4fECmGco\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 2 \u2014 displaced pts","x":{"dtype":"f4","bdata":"XtlpPDRKOj0Qua09mx8HPiSDPj5q\u002fn0+SHuhPpx+xj5TM+4++D0MP0O6Ij+L6zo\u002flDRWP81EeD+gnpQ\u002f4gXPP\u002fg7JkC6KmZABNiIQBoImEBD+J9Al4ymQIypr0BIFL9A"},"y":{"dtype":"f4","bdata":"0gHLPbRimz5KYQ4\u002fGjhbPzsqmT\u002fMuck\u002f6oX9P2DbGUBNEzZARFtTQF1ScUAUR4hA7f+YQO7srEBvUsdAXhf8QJIzIEG+SiJBDOoNQRnx7kBbFdFApYC1QKDti0BrT+w\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 3 \u2014 displaced pts","x":{"dtype":"f4","bdata":"uEcsPDDDEj1P2Z09tv0XPrTfgD44k8M+IzoKPwSVOT8Aj20\u002fNK2SP02Irz\u002fR8sw\u002fLkPtP+sBCkAYDyBAss00QBiWRkBZmFZA\u002fwJpQH4lgUAeZJFAkEahQN3zsEAoVcFA"},"y":{"dtype":"f4","bdata":"9I6VPU2Mdj5qjAE\u002fiP91PwaUzD8kvhdAKJxQQGxuh0AB0aZAK1fFQM9q4UCybvpAzR4JQZOjFEH2Nh5BDOsjQf2tJUGAQCVByWQhQQjFFkHVZwJB3PrLQHKghUDQarY\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 4 \u2014 displaced pts","x":{"dtype":"f4","bdata":"m6VpPFxyOT1PlLM99YsdPq7sej4a77Y+Vtr7PibOJj9+11Y\u002fw6CFP87joT8qCsI\u002fE7zmPwSlBUBqPxhAdhAtQDNxQ0A7aVxAEuJzQHgAhUDd4JJA3NuhQCKysEDqs8BA"},"y":{"dtype":"f4","bdata":"5NTKPcS2mj4uHRM\u002ffdF+P8Bkxz+mlg5ANqk\u002fQIyudkDhYZlApqG3QEnS1EAbgvFAodMGQUhHEkFDGxtB2gAiQXhrJUG1SyRBe1IdQYpWEkGfMwBBZLPJQHfhhkAee8U\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 5 \u2014 displaced pts","x":{"dtype":"f4","bdata":"Oh4bPMG+6Ty+rZQ92WYUPuZTbT4KZ64+nonxPlAcID984Uw\u002fail\u002fP25Emz8QWbk\u002f7ljaPxEN\u002fz8BVhRAX6MqQDJZQkC2TVlA2mhwQN7DhUCAuZRAtMCkQNZWtUCCS8NA"},"y":{"dtype":"f4","bdata":"6qiGPez6Qj6WRfQ+wExwP9IPvT+bVAhAHms4QK3hbUDPZJNAVdiwQI8VzkC\u002fMepAd2oCQZPgDkFTcxlB1WMhQTZUJUGCziRBXqMeQcB1EUHGQPpAQE29QHhQYEB9fIc\u002f"},"type":"scatter"},{"marker":{"size":8,"symbol":"cross"},"mode":"markers","name":"Initial Gauss pts","x":{"dtype":"f4","bdata":"kqGyO\u002fZJ3zxHI5E9OY4LPgLfZD4AQqo+lj7tPqSyHT8JW0o\u002feph8P3s1mj8+6bg\u002fiGfaP1qw\u002fj\u002fY4RJAxtAnQPgkPkBu3lVAJ\u002f1uQJLAhEAytZJAclyhQFS2sEDYwsBA"},"y":{"dtype":"f4","bdata":"YBIbPZf2Oj4gjO4+bEFiP8yitj\u002fTQgVAdmc1QCa1akAu4JFAx2KvQPIBzUALzulAsW8CQc\u002fGDkHtyRhBB6ogQZH6JEERXyVBES0fQQ2gEkFVdABBWKXLQPfMhkAKFsQ\u002f"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %% [markdown]
# On plotte $u$ aux points de Gauss en fin de training (qui sont sont donc indicateurs de comment on été déplacés les noeuds du maillage) et aux points de Gauss initiaux (sauvegardés suite à l'initialisation).

# %%
model.eval()

x_test = torch.linspace(0, 6.28, 50)

# ======================
# PARAMÈTRES MANUELS
# ======================
E1 = 110.0
E2 = 900.0

# --- run 1 ---
E_test = torch.tensor([E1, E2])
plot_displacement_field(model, E_test)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="697c0b73-2a7f-47a2-8a1e-557747ef5487" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("697c0b73-2a7f-47a2-8a1e-557747ef5487")) {                    Plotly.newPlot(                        "697c0b73-2a7f-47a2-8a1e-557747ef5487",                        [{"mode":"markers","name":"E = 110","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAAHFMUCbra5AmxoAQWbAJkG4HEtBcWxtQZTAhkEmY5VBEhGjQVqvr0E4PLtBamzFQRMKz0GqWtdBrkzfQfzp5kEZ8+1BaKfzQYuJ90GLv\u002fpB6if9QUbZ\u002fUHpPf5BHI\u002f8QZV\u002f+kElIvpBEy36QeLg+EE5n\u002fZBelTyQUKc7EFrdudBnU\u002fiQQjP20Fn19JBqvzJQYptwEF8yLVBC3KpQfjQnEE4M5BBDTaBQeDUYUG4v0BBMpIeQc+v7UDjz51A5s8dQF+HgTY="},"type":"scatter"},{"mode":"markers","name":"E = 900","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAN4Y4T7sW1s\u002fN9OgP6au0T\u002f5LABANHMWQOsMLECnm0BAKbZTQAvoZUADqXdAOwmEQMi9i0B6apJA8cuYQPfPnkALbaRAwhOpQDAirUAdb7BAx6qyQBeGtEAAPrVA+ZS1QI7otUCmP7VAnyG0QPqyskDG8K9Ah8SsQK9YqUDOEKVAasagQI1hnEAj1pZAE8WQQC\u002f5iUB8SoJAd690QLzsYkBSi05Af8o5QBYpIkBNDQpABI3hP1BErD+YFWc\u002fihXnPmD5ADQ="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444 ...

# %% [markdown]
# ### Midpoint deflection versus $E$

# %%
plot_midpoint_vs_E(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="bb8342d6-6a7f-4fae-b97b-066c7a9e5b65" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bb8342d6-6a7f-4fae-b97b-066c7a9e5b65")) {                    Plotly.newPlot(                        "bb8342d6-6a7f-4fae-b97b-066c7a9e5b65",                        [{"mode":"markers","name":"PGD model","x":{"dtype":"f4","bdata":"..."},"y":[31.725093841552734,31.466907501220703,31.20871925354004,30.95052719116211,30.692340850830078,29.74486541748047,28.698928833007812,27.65299415588379,26.607059478759766,25.734817504882812,24.92047119140625,24.106121063232422,23.291772842407227,22.500442504882812,21.72292137145996,20.945398330688477,20.167875289916992,19.49555778503418,18.928442001342773,18.361326217651367,17.794212341308594,17.276256561279297,16.8402156829834,16.404170989990234,15.96812915802002,15.550207138061523,15.186674118041992,14.823143005371094,14.459610939025879,14.103706359863281,13.801197052001953,13.498686790466309,13.196175575256348,12.89366626739502,12.634239196777344,12.3748140335083,12.115387916564941,11.855961799621582,11.627955436706543,11.404437065124512,11.180920600891113,10.957403182983398,10.755807876586914,10.561522483825684,10.367236137390137,10.17294979095459,9.994067192077637,9.82442855834961,9.654787063598633,9.485148429870605,9.325923919677734,9.177116394042969,9.02830982208252,8.879501342773438,8.737302780151367,8.606139183044434,8.47497272491455,8.3438081741333,8.216391563415527,8.10018539428711,7.983980655670166,7.8677754402160645,7.753159046173096,7.6496686935424805,7.546180725097656,7.442691326141357,7.339202880859375,7.246463775634766,7.1537251472473145,7.0609869956970215,6.968247890472412,6.8837738037109375,6.800478458404541,6.717185974121094,6.633890151977539,6.556079864501953,6.480098247528076,6.404116153717041,6.3281331062316895,6.2574543952941895,6.189955234527588,6.122457027435303,6.054959297180176,5.988566875457764,5.923283100128174,5.857998371124268,5.7927141189575195,5.732172012329102,5.679536819458008,5.626901149749756,5.574264049530029,5.519731521606445,5.459507465362549,5.399284362792969,5.339061260223389,5.281238079071045,5.240210056304932,5.199182033538818,5.1581549644470215,5.117125988006592],"type":"scatter"},{"line":{"color":"red","dash":"dash"},"mode":"lines","name":"Analytical u(L\u002f2)","x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"JjFFQmPCNELS2iZCw+8aQoObEELKkQdCjDD\\u002fQMJ9+0AE5vdAMGj0QC8D8UD9te1Ao3\u002fqQDdf50DbU+RAvlzhQBd53kArqNtAROnYQLg71kDlntNALxLRQASVzkDWJsxAIcfJQGR1x0AmMcVA8\u002fnCQFnPwEDwsL5AUZ68QByXukDzmrhAfam2QGPCtEBV5bJAAxKxQCJIr0Bqh61Ak8+rQF4gqkCHeahA0tqmQANEpUDhtKNANS2iQMqsoEBsM59A7MCdQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...

# %% [markdown]
# ### Compared to the ref solution

# %%
compute_error_vs_ref(model, model_ref, plot=True)
# Out:
# === Error vs. reference ===
#   relative_norm             : 1.5974e-01
#   mean_relative_error       : 6.7177e-02
#   max_relative_error        : 8.2476e+00
#   l2_absolute               : 1.8635e+00
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="a9f4cb43-6d57-4cfb-ab49-e20b606411cc" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a9f4cb43-6d57-4cfb-ab49-e20b606411cc")) {                    Plotly.newPlot(                        "a9f4cb43-6d57-4cfb-ab49-e20b606411cc",                        [{"colorbar":{"len":0.75,"title":{"text":"Rel Error"},"y":0.625},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"name":"Heatmap","x":{"dtype":"f4","bdata":"AAAAAN7pgT3e6QE+zd5CPt7pgT5WZKI+zd7CPkRZ4z7e6QE\u002fGicSP1ZkIj+RoTI\u002fzd5CPwkcUz9EWWM\u002fgJZzP97pgT98CIo\u002fGieSP7hFmj9WZKI\u002f84KqP5Ghsj8vwLo\u002fzd7CP2v9yj8JHNM\u002fpzrbP0RZ4z\u002fid+s\u002fgJbzPx61+z\u002fe6QFALfkFQHwICkDLFw5AGicSQGk2FkC4RRpAB1UeQFZkIkCkcyZA84IqQEKSLkCRoTJA4LA2QC\u002fAOkB+zz5Azd5CQBzuRkBq\u002fUpAuQxPQAgcU0BXK1dApjpbQPVJX0BEWWNAk2hnQOJ3a0Awh29Af5ZzQM6ld0AdtXtAbMR\u002fQN7pgUCF8YNALfmFQNQAiEB7CIpAIxCMQMoXjkByH5BAGSeSQMEulEBoNpZAED6YQLdFmkBfTZxABlWeQK5coEBVZKJA\u002fWukQKRzpkBMe6hA84KqQJqKrEBCkq5A6ZmwQJGhskA4qbRA4LC2QIe4uEAvwLpA1se8QH7PvkAl18BAzd7CQHTmxEAc7sZAw\u002fXIQA=="},"y":{"dtype":"f4","bdata":"AADIQhW87EIVvAhDIBobQyp4LUM01j9DPzRSQ0qSZENU8HZDL6eEQzTWjUM6BZdDPzSgQ0RjqUNKkrJDT8G7Q1TwxENZH85DXk7XQ2R94ENprOlDbtvyQ3QK\u002fEO8nAJEPzQHRMHLC0REYxBExvoUREmSGUTMKR5ETsEiRNFYJ0RT8CtE1ocwRFkfNUTbtjlEXk4+RODlQkRjfUdE5hRMRGisUETrQ1VEbttZRPByXkRzCmNE9qFnRHg5bET70HBEfWh1RAAAekQ="},"z":{"dtype":"f4","bdata":"AAAAADb\u002fbz63rng+zVZ5PjVcez74M3s+ExB+PqjdfT4ZFYA+knaAPjxwgT5z8oI+dO2CPvAshD4YSIU+xduFPocphz5f\...\...\u002f1c+C2xUPhIHWj4H+Fw+TfhcPkH4XD52+Fw+5PdcPtHoAUEAAAAAveLXPc4cwj2Sja49tz+oPfW9oD2NhqI9y\u002fedPUosoD2NZZ8990ihPXFvpj0LMaQ9jSqoPWDCqz1hPa09RgyyPUa9uT3zybo90sC+Pe6ywj0Qusg9qDXJPdTszD3Kt9Q9vo3bPbNM2z0uSd09npbkPZgY7D2Bteo9vPjoPWVk6j2jo+w9s9bsPYV36T3vi+o9s3vtPcKW9D2G7\u002fg9ALH5PYyY+z3qav49PTQDPm3LBz4CBAg+sNwIPnTZCj48sA8+aoIUPqbyFz4xYhg+cTUWPrQsFD5UIRI+r9UQPsB7ED6MJgs+nq4HPngMBz7RZwY+Z4EIPoK8Cj5Ykwk+jxwHPhqUBD4D+gE+aZj+PR2N\u002fT16DAA+PM38PcoQ+D3oM\u002fM9GwzwPcV27j0eXO09plnqPdGo5D1tJuE9ImvePXl42z0p6tk9vj\u002fXPV1C1j1xwdA92JPHPQHVxT1rW8Y9FPfGPUGtxz0+fM09MWvUPVqPzD2pvNk9mKbgPUun4D0ap+A9k6fgPVem4D2Xtv9AAAAAAID5uj2Dv6M9mHSPPZ2LiD1kN4A9Kc+APb\u002f9dT3Vcnc9zOxzPQ97cz2q2Xo92A5zPasvdz2qN3s9fL96PbS3fz3\...\u002f1QAAAAABQ4Jw9O5aFPd9\u002fYj1\u002f\\u002fDj32Fgo9frcJPSYl8Dw9QNE80HO5PH9GoTwYjaE8RrSiPN77kjwyiIs8ouKDPOgleDwDEGg8heF\u002fPJljizzBd2M8S4AqPL6z3zu\u002fh4w7zkQxO91Wtzo52Wk6mzeLO4qzzjvMSwE8MUsdPKNZKTysM0A8YdFHPCWCfDznZKk8RcO4PLhfwTwKVss8hgHXPDxpyzyo\\u002fmqTxJAIo8sihbPE5vLDx+8Pk7u8f3O8jj+DuaVro7RP6lO+wmkTvi53c7uUVMO8ZOnDtZZcc7Oqc9OzUkyDk8bXU7XwbEO9to6zvcBgQ8Fk0hPDK9VDwh\u002fnI8BFmEPMgNkDzAOZI8d5+ZPHV7mTy1E7M8mTTdPOjl7TyFKvk8ERoDPda8Cj1XTQY9g2IAPUcFJT0+LSM9fjUiPQc0Ij1BNCI9GzMiPWw2Ij3YidRAAAAAAB\u002fsID30pAM9VdrpPCzj6DzZ8dU8nHrcPLgmyDzpVcg8rdrBPK7EuDwDyME8 ...
# ({'relative_norm': 0.15973614156246185,
#   'mean_relative_error': 0.06717678159475327,
#   'max_relative_error': 8.247642517089844,
#   'l2_absolute': 1.8634976148605347},
#  tensor([[0.0000e+00, 1.4252e+00, 2.8086e+00,  ..., 2.4634e+00, 1.2317e+00,
#           3.8932e-06],
#          [0.0000e+00, 1.3642e+00, 2.7010e+00,  ..., 2.4220e+00, 1.2110e+00,
#           3.8327e-06],
#          [0.0000e+00, 1.3032e+00, 2.5935e+00,  ..., 2.3806e+00, 1.1903e+00,
#           3.7721e-06],
#          ...,
#          [0.0000e+00, 2.0650e-01, 4.0343e-01,  ..., 4.1873e-01, 2.0936e-01,
#           1.0951e-07],
#          [0.0000e+00, 2.0307e-01, 3.9662e-01,  ..., 4.1296e-01, 2.0648e-01,
#           1.0584e-07],
#          [0.0000e+00, 1.9965e-01, 3.8982e-01,  ..., 4.0720e-01, 2.0360e-01,
#           1.0217e-07]]),
#  tensor([[0.0000, 1.8615, 3.7094,  ..., 3.5031, 1.7515, 0.0000],
#          [0.0000, 1.6591, 3.2872,  ..., 3.0885, 1.5443, 0.0000],
#          [0.0000, 1.4567, 2.8650,  ..., 2.6740, 1.3370, 0.0000],
#          ...,
#          [0.0000, 0.2060, 0.4100,  ..., 0.3870, 0.1935, 0.0000],
#          [0.0000, 0.2004, 0.3967,  ..., 0.3726, 0.1863, 0.0000],
#          [0.0000, 0.1948, 0.3834,  ..., 0.3582, 0.1791, 0.0000]]))

# %% [markdown]
# ## r-adapt + nodal values all + meshes all + different meshes

# %% [markdown]
# ### Training and definition

# %%
N_u           = 25
nodes_u       = torch.linspace(0,6.28,N_u)
nodes_u       = nodes_u[:,None] # pq il l etend ?
nodes_u_non_uniform = square(nodes_u)/nodes_u[-1]
elements_u    = torch.vstack([torch.arange(0,N_u-1),torch.arange(1,N_u)]).T

N_E = 25
nodes_E =   torch.linspace(1e2, 1e3, N_E)
nodes_E =   nodes_E[:,None]
elements_E    = torch.vstack([torch.arange(0,N_E-1),torch.arange(1,N_E)]).T

# %%
results_4 = {}
max_num_mode_4 = 3

# train_PGD(
#     nodes_u=nodes_u,
#     elements_u=elements_u,
#     nodes_E=nodes_E,
#     elements_E=elements_E,
#     max_num_mode    = max_num_mode_4,
#     Nepoch          = [250, 200, 200, 1000, 1000],
#     save_plot_rate       = 200,
#     lr              = [1e-2, 1e-3, 1e-4, 1e-4, 1e-4],
#     r_adaptivity    = True,
#     mode_by_mode_nodal_values = False,
#     mode_by_mode_r_adapt      = False,
#     shared_mesh     = False,
#     train_first_mesh= True,
#     eta             = 1e-8,
#     optimizer_type='Adam',
#     fault_amp       = 0,           # On ajoute de l'asymétrie
#     results = results_4,
#     # log_parameters=True
# )

train_PGD(
    nodes_u=nodes_u_non_uniform,
    elements_u=elements_u,
    nodes_E=nodes_E,
    elements_E=elements_E,
    max_num_mode    = max_num_mode_4,
    Nepoch          = [300, 1200, 2000, 500, 500],
    save_plot_rate       = 100,
    lr              = [1e-2, 1e-3, 1e-4, 1e-4, 1e-4], #[1e-2, 1e-2, 1e-3, 1e-4, 1e-4] diverges [1e-2, 1e-3, 1e-4, 1e-4, 1e-4]
    r_adaptivity    = True,
    mode_by_mode_nodal_values = False,
    mode_by_mode_r_adapt      = False,
    shared_mesh     = False,
    train_first_mesh= True,
    eta             = 1e-8,
    optimizer_type=['AdamW', 'AdamW', 'AdamW'],
    fault_amp       = 0,           # On ajoute de l'asymétrie
    results = results_4,
    # log_parameters=True
)
# Out:
# i = 1999 | loss = -2.34e+07
# stagnation indicator = 4.230122e-03

# %%
## Unpacking

model = results_4['model']
lossLists = results_4['lossLists']
x_gauss_ini = results_4['x_gauss_ini']

## Saving
# torch.save(model.state_dict(), "model_weights_4.pt")

# %% [markdown]
# ### Total loss

# %%
plot_loss(lossLists)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="7b2dffc1-2045-4c7b-8016-fa89ea4b8d17" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7b2dffc1-2045-4c7b-8016-fa89ea4b8d17")) {                    Plotly.newPlot(                        "7b2dffc1-2045-4c7b-8016-fa89ea4b8d17",                        [{"line":{"color":"#01426a"},"mode":"lines","name":"Loss","y":[-43501.25,-170239.375,-285948.875,-391740.0625,-488564.625,-577292.0,-658849.5,-734201.1875,-804263.75,-869860.1875,-931739.0,-990600.0625,-1047103.375,-1101854.25,-1155390.0,-1208174.0,-1260604.75,-1313022.375,-1365718.75,-1418942.0,-1472896.0,-1527750.0,-1583646.5,-1640706.0,-1699023.75,-1758670.0,-1819695.75,-1882142.375,-1946041.875,-2011419.75,-2078283.75,-2146631.5,-2216459.5,-2287761.5,-2360531.5,-2434755.25,-2510419.25,-2587502.75,-2665983.5,-2745840.25,-2827054.75,-2909607.75,-2993472.0,-3078619.5,-3165021.75,-3252651.75,-3341474.25,-3431456.5,-3522566.0,-3614766.0,-3708021.0,-3802286.0,-3897526.5,-3993702.25,-4090771.25,-4188695.5,-4287433.0,-4386950.0,-4487213.5,-4588192.5,-4689867.5,-4792216.5,-4895232.5,-4998909.5,-5103238.5,-5208214.5,-5313844.0,-5420121.5,-5527045.0,-5634619.0,-5742839.0,-5851703.0,-5961203.5,-6071340.0,-6182104.5,-6293492.5,-6405496.0,-6518103.0,-6631307.5,-6745094.5,-6859448.5,-6974353.5,-7089789.0,-7205729.0,-7322145.0,-7439007.5,-7556279.0,-7673924.0,-7791906.5,-7910198.0,-8028763.0,-8147571.5,-8266600.0,-8385814.0,-8505150.0,-8624516.0,-8744243.0,-8864330.0,-8984106.0,-9104216.0,-9224486.0,-9344581.0,-9465065.0,-9585396.0,-9705832.0,-9826399.0,-9946773.0,-10067328.0,-10187734.0,-10308060.0,-10428401.0,-10548503.0,-10668540.0,-10788438.0,-10908062.0,-11027583.0,-11146852.0,-11265842.0,-11384658.0,-11503184.0,-11621394.0,-11739352.0,-11857018.0,-11974319.0,-12091298.0,-12207960.0,-12324262.0,-12440168.0,-12555694.0,-12670834.0,-12785559.0,-12899842.0,-13013654.0,-13126984.0,-13239810.0,-13352116.0,-13463877.0,-13575066.0,-13685674.0,-13795666.0,-13905038.0,-14013770.0,-14121846.0,-14229266.0,-14336039.0,-14442201.0,-14547746.0,-14652630.0,-14756782.0,-14860208.0,-14962896.0,-15064890.0,-15166215.0,-15266837.0,-15366678.0,-15465672.0,-15563804.0,-15661026.0,-15757318.0,-15852667.0,-15947074.0,-16040513.0,-16132928.0,-16224309.0,-16314612.0,-16403808.0,-16491918.0,-16578944.0,-16664917.0,-16749837.0,-16833736.0,-16916648.0,-16998640.0,-17079692.0,-17159724.0,-17238706.0,-17316692.0,-17393684.0,-17469692.0,-17544704.0,-17618728.0,-17691700.0,-17763540.0,-17834188.0,-17903666.0,-17971976.0,-18039104.0,-18105004.0,-18169676.0,-18233150.0,-18295390.0,-18356348.0,-18415984.0,-18474280.0,-18531268.0,-18586902.0,-18641172.0,-18694068.0,-18745652.0,-18795978.0,-18845092.0,-18893044.0,-18939882.0,-18985676.0,-19030592.0,-19074956.0,-19118852.0,-19162036.0,-19204362.0,-19246048.0,-19287340.0,-19328334.0,-19368872.0,-19408784.0,-19448148.0,-19487224.0,-19525912.0,-19563964.0,-19601412.0,-19638480.0,-19675096.0,-19711100.0,-19746564.0,-19781582.0,-19816130.0,-19850172.0,-19883762.0,-19916896.0,-19949570.0,-19981842.0,-20013736.0,-20045204.0,-20076264.0,-20106972.0,-20137336.0,-20167348.0,-20196988.0,-20226294.0,-20255276.0,-20283922.0,-20312256.0,-20340260.0,-20367950.0,-20395324.0,-20422380.0,-20449132.0,-20475598.0,-20501758.0,-20527620.0,-20553196.0,-20578482.0,-20603500.0,-20628228.0,-20652698.0,-20676900.0,-20700828.0,-20724516.0,-20747948.0,-20771124.0,-20794060.0,-20816756.0,-20839208.0,-20861440.0,-20883444.0,-20905210.0,-20926754.0,-20948076.0,-20969194.0,-20990082.0,-21010774.0,-21031248.0,-21051512.0,-21071574.0,-21091432.0,-21111072.0,-2113050 ...

# %% [markdown]
# ### Nodes displacement (only for r - adaptivity)

# %%
plot_node_displacement(model, nodes_u_non_uniform)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="db721d9c-3f18-4fa6-8852-a8c0527c9d9f" class="plotly-graph-div" style="height:350px; width:750px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("db721d9c-3f18-4fa6-8852-a8c0527c9d9f")) {                    Plotly.newPlot(                        "db721d9c-3f18-4fa6-8852-a8c0527c9d9f",                        [{"name":"Mode 1","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAHijibsge7y6YPcaPODwDD3EvJo9TmkIPsZVVT50r5k+GKnPPrhfBj+y0Cc\u002fyBFLP0JkbT8DG4M\u002fMjpoPzAjnD7cEkS\u002fBgaiv7ZeoL+4XIm\u002fEMNTv3hTD79Q\u002foy+AAAAAA=="},"type":"bar"},{"name":"Mode 2","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAACjOr7tga7y6wHItu0AzbLvA4Ya7AMunuwDTJrsAMCk6AA6MOwB5DTwAzV88gGrEPAB\u002fujsAB6q8AD0HvYD8n7wAKze8ANbyu4A8nDwA6Es8AGIgPABwJTsAgEk7AAAAAA=="},"type":"bar"},{"name":"Mode 3","opacity":0.5,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGA=="},"y":{"dtype":"f4","bdata":"AAAAAJzzRLugL726gOJcugAgKjgAGZ86gK8tO4C1rTsAwQk8wCZEPMAigjzAL6Q8AO\u002fEPMBb1jyA2dQ8gHWzPABN0jyAPOg8AAXmPADMmzwAqpo8AGIgPAA4yTsA0Kg6AAAAAA=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"err ...

# %% [markdown]
# ### Different modes

# %%
plot_modes(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="2a04ed47-6d90-45b6-b4c9-cfe99c27afe2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2a04ed47-6d90-45b6-b4c9-cfe99c27afe2")) {                    Plotly.newPlot(                        "2a04ed47-6d90-45b6-b4c9-cfe99c27afe2",                        [{"mode":"lines","name":"Mode 1","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5mQO1DaED4SGpAA05sQA5TbkAYWHBAI11yQC5idEA5Z3ZARGx4QE9xekBadnxAZXt+QDhAgEC+QoFAQ0WCQMlHg0BOSoRA1EyFQFlPhkDfUYdAZFSIQOlWiUBvWYpA9FuLQHpejED\u002fYI1AhWOOQApmj0CQaJBAFWuRQJttkkAgcJNApnKUQCt1lUCxd5ZANnqXQLx8mEBBf5lAx4GaQEyEm0DShpxAV4mdQN2LnkBijp9A6JCgQG2ToUDzlaJAeJijQP6apECDnaVACaCmQI6ip0AUpahAmaepQB6qqkCkrKtAKa+sQK+xrUA0tK5AuravQD+5sEDFu7FASr6yQNDAs0BVw7RA28W1QGDItkDmyrdAa824QPHPuUB20rpA\u002fNS7QIHXvEAH2r1AjNy+QBLfv0CX4cBAHeTBQKLmwkAo6cNArevEQDPuxUC48MZAPvPHQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAACpWDL6Q39a9XJ9EPNP4Aj5OuHg+0d62PvKy8D6LJxU\u002fyosxP9jSTT9no2k\u002fLp2CPwDXjz\u002fRNpw\u002fo5aoPzGltD9fp8A\u002f26HMP9RI2D\u002fO7+M\u002fx5bvP+rf+j8AEwNACrYIQHNBDkBOpxNAJw0ZQAFzHkDa2CNAVfkoQKAZLkDsOTNANlo4QIN6PUDNmkJAM4NHQBxYTEAELVFA7AFWQNPWWkC7q19Ao4BkQItVaUBzKm5AW\u002f9yQELUd0AsqXxACr+AQE8mg0AGboRAvrWFQHX9hkAtRYhA5IyJQJzUikBSHIxACmSNQMGrjkB4849AMDuRQOeCkkCeypNAVhKVQA5alkDFoZdAfOmYQDQxmkDreJtAosCcQFoInkARUJ9AyZegQIDfoUA3J6NA726kQKa2pUBd\u002fqZAFUaoQJ9DqUCbOKlAly2pQJMiqUCOF6lAigypQIYBqUCC9qhAfeuoQHrgqEB21ahAccqoQG2\u002fqEBotKhAZKmoQGCeqEBck6hAWIioQFR9qEBPcqhAS2eoQEZcqEBCUahAPkaoQDo7qEA2MKhAMiWoQC0aqEApD6hAJQSoQCH5p0Ac7qdAGOOnQBTYp0AQzadADMKnQAe3p0ADrKdA\\u002flAQGv9O0DBATdAHAYyQHcKLUDNDihAKBMjQH4XHkAYyhhANGgTQFgGDkB0pAhAmEIDQG7B+z+IufA\u002fmFblP6nz2T+6kM4\u002f1C3DP+TKtz8KZKw\u002fTqegP5vqlD\u002ffLYk\u002fWuJ6P+BoYz9870s\u002fj1wzPxG9GT96HQA\u002fJvzMPvm8mT5W\u002fEw+9vvMPQAAAAA="},"type":"scatter"},{"mode":"lines","name":"Mode 2","x":{"dtype":"f4","bdata":"AAAAAL5CAT2+QoE9HeTBPb5CAT5ukyE+HeRBPsw0Yj6+QoE+FmuRPm6ToT7Fu7E+HeTBPnUM0j7MNOI+JF3yPr5CAT\u002fqVgk\u002fFmsRP0J\u002fGT9ukyE\u002fmacpP8W7MT\u002fxzzk\u002fHeRBP0n4ST91DFI\u002foSBaP8w0Yj\u002f4SGo\u002fJF1yP1Bxej++QoE\u002f1EyFP+pWiT8AYY0\u002fFmuRPyx1lT9Cf5k\u002fWImdP26ToT+DnaU\u002fmaepP6+xrT\u002fFu7E\u002f28W1P\u002fHPuT8H2r0\u002fHeTBPzPuxT9J+Mk\u002fXwLOP3UM0j+LFtY\u002foSDaP7cq3j\u002fMNOI\u002f4j7mP\u002fhI6j8OU+4\u002fJF3yPzpn9j9Qcfo\u002fZnv+P75CAUDJRwNA1EwFQN9RB0DqVglA9VsLQABhDUALZg9AFmsRQCFwE0AsdRVAN3oXQEJ\u002fGUBNhBtAWIkdQGOOH0BukyFAeJgjQIOdJUCOoidAmacpQKSsK0CvsS1AurYvQMW7MUDQwDNA28U1QObKN0DxzzlA\u002fNQ7QAfaPUAS3z9AHeRBQCjpQ0Az7kVAPvNHQEj4SUBT\u002fUtAXgJOQGkHUEB0DFJAfxFUQIoWVkCVG1hAoCBaQKslXEC2Kl5AwS9gQMw0YkDXOWRA4j5 ...

# %% [markdown]
# ### Displacement of the Gauss point (trick)

# %%
plot_gauss_displacement(model, x_gauss_ini)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="376ed9c3-bafb-4af9-a6ab-9ca78c3212a6" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("376ed9c3-bafb-4af9-a6ab-9ca78c3212a6")) {                    Plotly.newPlot(                        "376ed9c3-bafb-4af9-a6ab-9ca78c3212a6",                        [{"mode":"markers","name":"Mode 1 \u2014 displaced pts","x":{"dtype":"f4","bdata":"TnP3Oz5i9jzH7Ig9xjDqPbaRLD4noGk+0s6VPho4uT7KCeA+V34FP8FSHT9AYTg\u002fDJRYP8nJgT+kJ6o\u002fTQcBQCHlTEAmcYtALMufQAD4qUD6HLFA2o23QH4TvkDLKsVA"},"y":{"dtype":"f4","bdata":"4\u002fVrPd98Sz7m\u002f9k+uHE3PwZ5hT8nebI\u002fxTDiP2ILCkBvviRAzWJBQN0FYEA2yoBAtseTQCxxq0A2PdNAc3IJQToSHUF4PgZB4yzNQO5hpUAMZoRAnj5JQDuDAUAItDg\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 2 \u2014 displaced pts","x":{"dtype":"f4","bdata":"U0QFPBYn+zzpUZU9hsEOPvDSaD5Zn6w+ADXvPubwHT\u002fUuUk\u002fefF6PzXImD+cgLY\u002fdIHYPyqn\u002fz9amhRAPX8pQIogP0C6dlZAoZ1uQHo\u002fhEAgWpJAAiqhQGWfsEBAtsBA"},"y":{"dtype":"f4","bdata":"Yih+PZArTz4LHu0+mF1ePznjsT+ORwFAXQMvQP7NYEBUMItAzNCmQMTPwkCv091AfnT4QFDCCEGHxxJBuYcZQY6THEHmOxxBLJgXQZhuDUEm0fhAOxjIQBrBhkBJocc\u002f"},"type":"scatter"},{"mode":"markers","name":"Mode 3 \u2014 displaced pts","x":{"dtype":"f4","bdata":"ed7jO62C8TyJepM9WvcLPpk6ZD7ERKk+fDXrPmzxGz84v0c\u002foAd5P9bolz8BF7Y\u002f8zDXP\u002fBZ+z+KWRFABEsmQG9qPEAuEFRAV3ttQFclhEDEP5JAMhuhQOaXsECSvcBA"},"y":{"dtype":"f4","bdata":"0ElZPYm5Rz4CR+o+XCJaP8CHrj9J5P0\u002fcE4sQLhGXkBHC4pASsqlQOb3wUAhed1ApYH3QCWHB0FxdRFByNAYQWRjHEGrcRxBS+oXQR+IDUEyHPlAJk\u002fIQBnlhkBg\u002fMY\u002f"},"type":"scatter"},{"marker":{"size":8,"symbol":"cross"},"mode":"markers","name":"Initial Gauss pts","x":{"dtype":"f4","bdata":"kqGyO\u002fZJ3zxHI5E9OY4LPgLfZD4AQqo+lj7tPqSyHT8JW0o\u002feph8P3s1mj8+6bg\u002fiGfaP1qw\u002fj\u002fY4RJAxtAnQPgkPkBu3lVAJ\u002f1uQJLAhEAytZJAclyhQFS2sEDYwsBA"},"y":{"dtype":"f4","bdata":"NFYqPZenOT68quY+6IJZP9\u002f\u002frj+yRP8\u002fOa8tQDR\u002fYECSjYtAfLOnQMMwxEBx5N9ASNP5QK17CEGzFBJBtycZQRiCHEE6SRxBJX0XQXzwDEHozfdAPl3HQPhShkB\u002fhcY\u002f"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd37 ...

# %% [markdown]
# On plotte $u$ aux points de Gauss en fin de training (qui sont sont donc indicateurs de comment on été déplacés les noeuds du maillage) et aux points de Gauss initiaux (sauvegardés suite à l'initialisation).

# %%
model.eval()

x_test = torch.linspace(0, 6.28, 50)

# ======================
# PARAMÈTRES MANUELS
# ======================
E1 = 110.0
E2 = 900.0

# --- run 1 ---
E_test = torch.tensor([E1, E2])
plot_displacement_field(model, E_test)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="0248863c-120d-4822-bb58-254ca4fa6e71" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0248863c-120d-4822-bb58-254ca4fa6e71")) {                    Plotly.newPlot(                        "0248863c-120d-4822-bb58-254ca4fa6e71",                        [{"mode":"markers","name":"E = 110","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAAKDCRECgwsRAOfMPQWt8O0FpJ2RBSxqGQXpRmEE56KlBmbW6QeatyUG4f9hBkKLlQY3b8UFTF\u002f1BXMgDQuVFCELxUwxC3AwQQqkKE0ILtBVCc9kXQkZVGUKYjxpC8SMbQgcsG0KugRpCOmYZQkDpF0IPsRVClg4TQgUWEEJZTgxCiVIIQrK5A0L\u002fH\u002f1BSc7xQSKm5UFofNhBOsTJQdmkukHa+alB8GqYQTXRhUHlVmRBRBc7QXANEEFn4MNASuBDQAAAAAA="},"type":"scatter"},{"mode":"markers","name":"E = 900","x":{"dtype":"f4","bdata":"AAAAADs9Az47PYM+2NvEPjs9Az+KDCQ\u002f2NtEPyerZT87PYM\u002f4qSTP4oMpD8xdLQ\u002f2NvEP4BD1T8nq+U\u002fzxL2Pzs9A0APcQtA4qQTQLbYG0CKDCRAXUAsQDF0NEAFqDxA2NtEQK4PTUCBQ1VAVXddQCmrZUD83m1A0BJ2QKRGfkA8PYNAJleHQA9xi0D5io9A46STQM2+l0C32JtAofKfQIoMpEB0JqhAXkCsQEhasEAydLRAHI64QAWovEDvwcBA2dvEQMP1yEA="},"y":{"dtype":"f4","bdata":"AAAAABwqoj4cKiI\u002fbvpuP3Cfkz8f76s\u002fS4vDPxAF2T8kF+0\u002fHF\u002f\u002fP\u002f++B0DAtw9A5SYYQE\u002fWIECzZShAmSgvQBcKNUD07TlAgTA+QGyWQUBOPERAot5FQP+4RkBZ\u002fkZAIMpFQASRRUBUl0ZAUpxGQHjDRUDeDURAqXxBQJknPkBV3jlAuig1QNwuL0AyiihARMQgQGgKGEClpA9AgcAHQA4\u002f\u002fz+fKu0\u002ftQ\u002fZPw1Uwz9eXKw\u002f1CuTP2LFbj\u002fHbCE\u002fsWyhPgAAAAA="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"], ...

# %% [markdown]
# ### Midpoint deflection versus $E$

# %%
plot_midpoint_vs_E(model)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="47e0e4a6-a2f2-4d7e-ae8d-d79bc11b83b2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("47e0e4a6-a2f2-4d7e-ae8d-d79bc11b83b2")) {                    Plotly.newPlot(                        "47e0e4a6-a2f2-4d7e-ae8d-d79bc11b83b2",                        [{"mode":"markers","name":"PGD model","x":{"dtype":"f4","bdata":"..."},"y":[40.26649856567383,38.98562240600586,37.70474624633789,36.42387390136719,35.14299392700195,33.86211395263672,32.58123779296875,31.30036163330078,30.01948356628418,28.73860740661621,27.45772933959961,26.176851272583008,25.045949935913086,23.9150447845459,22.784143447875977,21.653242111206055,20.5223388671875,19.391437530517578,18.260534286499023,17.129634857177734,15.998730659484863,14.867828369140625,13.736924171447754,13.846508979797363,13.956097602844238,14.065683364868164,14.175268173217773,14.284855842590332,14.394441604614258,14.5040283203125,14.613614082336426,14.723199844360352,14.832786560058594,14.942373275756836,14.251709938049316,13.56104564666748,12.870380401611328,12.179717063903809,11.489055633544922,10.79839038848877,10.10772705078125,9.417064666748047,8.726400375366211,8.035734176635742,7.345070838928223,7.687532424926758,8.029994010925293,8.372455596923828,8.714919090270996,9.057380676269531,9.3998441696167,9.742305755615234,10.084769248962402,10.427229881286621,10.769693374633789,11.112154960632324,10.519194602966309,9.926239013671875,9.333280563354492,8.740320205688477,8.147364616394043,7.554403305053711,6.9614458084106445,6.3684844970703125,5.775529384613037,5.182568073272705,4.5896100997924805,4.9893059730529785,5.3889970779418945,5.788691520690918,6.1883864402771,6.588078498840332,6.98777437210083,7.387467861175537,7.787163257598877,8.186854362487793,8.58655071258545,8.986244201660156,8.449409484863281,7.912574291229248,7.375739574432373,6.838904857635498,6.302069664001465,5.76522970199585,5.228400707244873,4.6915602684021,4.154725551605225,3.6178905963897705,3.0810558795928955,3.51019287109375,3.9393301010131836,4.368466854095459,4.797604084014893,5.226740837097168,5.655878067016602,6.085015296936035,6.514156818389893,6.943293571472168,7.372430801391602,7.801567077636719],"type":"scatter"},{"line":{"color":"red","dash":"dash"},"mode":"lines","name":"Analytical u(L\u002f2)","x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"JjFFQmPCNELS2iZCw+8aQoObEELKkQdCjDD\\u002fQMJ9+0AE5vdAMGj0QC8D8UD9te1Ao3\u002fqQDdf50DbU+RAvlzhQBd53kArqNtAROnYQLg71kDlntNALxLRQASVzkDWJsxAIcfJQGR1x0AmMcVA8\u002fnCQFnPwEDwsL5AUZ68QByXukDzmrhAfam2QGPCtEBV5bJAAxKxQCJIr0Bqh61Ak8+rQF4gqkCHeahA0tqmQANEpUDhtKNANS2iQMqsoEBsM59A7MCdQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2 ...

# %% [markdown]
# ### Compared to the ref solution

# %%
compute_error_vs_ref(model, model_ref, plot=True)
# Out:
# === Error vs. reference ===
#   relative_norm             : 1.1784e-01
#   mean_relative_error       : 1.5534e-01
#   max_relative_error        : 8.1298e-01
#   l2_absolute               : 1.3747e+00
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="346af19b-dd0f-4283-8ea9-9d0eaad01b13" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("346af19b-dd0f-4283-8ea9-9d0eaad01b13")) {                    Plotly.newPlot(                        "346af19b-dd0f-4283-8ea9-9d0eaad01b13",                        [{"colorbar":{"len":0.75,"title":{"text":"Rel Error"},"y":0.625},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"name":"Heatmap","x":{"dtype":"f4","bdata":"AAAAAN7pgT3e6QE+zd5CPt7pgT5WZKI+zd7CPkRZ4z7e6QE\u002fGicSP1ZkIj+RoTI\u002fzd5CPwkcUz9EWWM\u002fgJZzP97pgT98CIo\u002fGieSP7hFmj9WZKI\u002f84KqP5Ghsj8vwLo\u002fzd7CP2v9yj8JHNM\u002fpzrbP0RZ4z\u002fid+s\u002fgJbzPx61+z\u002fe6QFALfkFQHwICkDLFw5AGicSQGk2FkC4RRpAB1UeQFZkIkCkcyZA84IqQEKSLkCRoTJA4LA2QC\u002fAOkB+zz5Azd5CQBzuRkBq\u002fUpAuQxPQAgcU0BXK1dApjpbQPVJX0BEWWNAk2hnQOJ3a0Awh29Af5ZzQM6ld0AdtXtAbMR\u002fQN7pgUCF8YNALfmFQNQAiEB7CIpAIxCMQMoXjkByH5BAGSeSQMEulEBoNpZAED6YQLdFmkBfTZxABlWeQK5coEBVZKJA\u002fWukQKRzpkBMe6hA84KqQJqKrEBCkq5A6ZmwQJGhskA4qbRA4LC2QIe4uEAvwLpA1se8QH7PvkAl18BAzd7CQHTmxEAc7sZAw\u002fXIQA=="},"y":{"dtype":"f4","bdata":"AADIQhW87EIVvAhDIBobQyp4LUM01j9DPzRSQ0qSZENU8HZDL6eEQzTWjUM6BZdDPzSgQ0RjqUNKkrJDT8G7Q1TwxENZH85DXk7XQ2R94ENprOlDbtvyQ3QK\u002fEO8nAJEPzQHRMHLC0REYxBExvoUREmSGUTMKR5ETsEiRNFYJ0RT8CtE1ocwRFkfNUTbtjlEXk4+RODlQkRjfUdE5hRMRGisUETrQ1VEbttZRPByXkRzCmNE9qFnRHg5bET70HBEfWh1RAAAekQ="},"z":{"dtype":"f4","bdata":"AAAAAAshHj7q+Ro+xI4UPiWGDD78jQw+XoMQPm+FET5j6RE+KxkTPvPwFD4QexY+kiwTPjQXFT71KRc+3gkVPjiqFT7uLRc+cTQVPn+ZFT6+Zxc+F0IYPlbxFT75GhQ+pxUXPq7rGD6w0Bc+98IWPupYGD4OBho+dgsYPs0oGD6\u002frBg+4iwZPnB0Gj7ZHxk+Q9MXPs\u002fXGD4CERo+NgEaPmR3GD7Q2hc+VkAXPi7LGD7sdho+tiwYPn0mFj78XhY+RpcWPkzPFj7TBRc+5KoWPnpPFj6C8xU+vM4WPri7GD7PRRk+j0AXPpD9Fj6GuRY+cTkXPmLoGD5fnho+h0oYPnCEFz6tuBY+3+YVPq3MFj5rEhg+FGgZPuQmFz4ZyxQ+KnkTPo8rFD7C5hQ+fKsVPh0aFT5UvBM+pkQSPiawED6C+w4+X+UPPo\u002fLEj7p9BU++tMSPsi1Dj4pCAo+IOgJPldGCj7OtAo+V3AMPhMlFD7L6gk+Dgr6PaSZ3T0\u002fztc9AM7XPT\u002fP1z2Rz9c9AAAAAAAAAAABud89uIjOPR0bvT1JG6o9FuyoPUN0sD1BWLI9iw+zPfe1tT3I5Lk9kmO9PSOOtj32x7o93FG\u002fPU\u002fsuj2Kgbw9mwHAPYkRvD2bI7096y\u002fBPUYywz3Ydr49m7S6PWq9wD28XMQ957\u002fBPWVCvz06isI9kAbGPQi\u002fwT0M6sE9yO\u002fCPf3twz3EscY98ejDPc0wwT0lZMM9BQfGPVLuxT0awsI9NJvBPTR4wD1Y48M9yZPHPcjZwj3ss749XHS\u002fPSE0wD388sA9onnBPaJ0wD1cbr89lWa+PckFwD06+sM94fvEPTaLwD381b89+B2\u002fPSsRwD1rmcM9WjDHPWEywj3CgMA9ocK+PTf3vD2U6749JbHBPV2YxD1b3r89mey6Pb1BuD2KALo9e9W7PTvCvT3P2bw9\u002fsK5Pa9xtj1X37I9YgSvPeezsD0ClbY9NP68PUoYtj31JK09IfqiPblwoj1d6KI9y3SjPQLFpj3AFLc9yv6gPXI5hT1nGU49bs1BPRDNQT2dz0E9S9BBPQAAAAAAAAAAn\u002fRSPY5FET29ZcI8a4lLPKNgMzxVdWo8OHR3PLrhezyQv4k8euWcPIrmrDyYSJA8byOjPOpBtzwn1KQ8CNOsPJc8vTy2fq08mzSzPFqlxTzJPM88fr+7PEs+rDzFv8Q8B\u002fTSPCVgxjw4Yro8QA7IPGuu1jwi3MM8AzPEPG46yDz\u002fJMw8VUXYPJR5zDzD9MA8m5zKPEwk1jxk5NU8f7HIPLZzxDzFRMA8m7DPPPxD4Dw\u002flsw8UHi7PA0bwDx+ucQ8XFLJPDDzyzwHQcY8IojAPOzGujzjysA8ASrRPPfP1DxL9cA8oim9PLlOuTxb2rw8HNrLPFgY2zwXXsU8B9W9PJAUtjwrGa48DMO2PN0NwzwY6M88JOC7PBbspjweIJw8nfikPGVBrjy5Arg8S5i1PNFkpzwHJZg8\u002fbmHPMQCbDyTFXg8gwWUPFQrrjw7QY8834BPPAWH6ztRLN078kzfO+LO4Tu5BAo8GROLPEjAqDunfx48KAvRPJp96zxNfus87XjrPBl36zwAAAAAAAAAAGPb8Dv1oqI8i7b6PLPJKj0dRy89NZ4fPUtGGj2RaRc9g0IPPUYoAz0JFvI8dasGPX409zxnD+A8\u002fq7xPJji5jzXKtM8DnThPGt32Tx0S8Q8aI24POxyyzwScto81SjCPLWatDyQFsM8e+XQPKzWwjymtrM8CbLHPJWZxzy5ocM8x8W\u002fPHGgsjw7m748fk7KPMvVvzzeaLM8bluzPG6KwDxhBsQ8iXbHPGhhtjzFGaQ8mt63PKXdyDxrSMI8Jbq7PHAztTzWArI8xaG5PN9JwTwi\u002fcg8F+\u00 ...
# ({'relative_norm': 0.11783861368894577,
#   'mean_relative_error': 0.15533685684204102,
#   'max_relative_error': 0.8129798769950867,
#   'l2_absolute': 1.374716877937317},
#  tensor([[0.0000, 1.5740, 3.1480,  ..., 3.1339, 1.5670, 0.0000],
#          [0.0000, 1.4779, 2.9557,  ..., 2.9424, 1.4712, 0.0000],
#          [0.0000, 1.3817, 2.7634,  ..., 2.7508, 1.3754, 0.0000],
#          ...,
#          [0.0000, 0.2638, 0.5276,  ..., 0.5255, 0.2628, 0.0000],
#          [0.0000, 0.2949, 0.5897,  ..., 0.5875, 0.2937, 0.0000],
#          [0.0000, 0.3259, 0.6519,  ..., 0.6494, 0.3247, 0.0000]]),
#  tensor([[0.0000, 1.8615, 3.7094,  ..., 3.5031, 1.7515, 0.0000],
#          [0.0000, 1.6591, 3.2872,  ..., 3.0885, 1.5443, 0.0000],
#          [0.0000, 1.4567, 2.8650,  ..., 2.6740, 1.3370, 0.0000],
#          ...,
#          [0.0000, 0.2060, 0.4100,  ..., 0.3870, 0.1935, 0.0000],
#          [0.0000, 0.2004, 0.3967,  ..., 0.3726, 0.1863, 0.0000],
#          [0.0000, 0.1948, 0.3834,  ..., 0.3582, 0.1791, 0.0000]]))
